# %%
OPENAI_API_KEY = "<OPENAI API KEY>" # Replace this with your own OpenAI API key

# %%
import ast
import glob
import json
import os
import re
import sqlite3
import time
from typing import List, Optional

from func_timeout import func_timeout, FunctionTimedOut
import openai
from openai import APITimeoutError as OpenAITimeout
from openai import APIError
import pandas as pd
from requests.exceptions import Timeout as RequestsTimeout
import sqlglot
from sqlglot import expressions, Expression
import tiktoken

# %%
openai.api_key = OPENAI_API_KEY

REFERENCE_SET = "../bird-data-train"
REFERENCE_JSON = "train.json"
REFERENCE_DB = "train_databases"

REFERENCE_JSON = "./" + REFERENCE_SET + "/" + REFERENCE_JSON
REFERENCE_DB_DIR = "./" + REFERENCE_SET + "/" + REFERENCE_DB

SET = "../bird-data-dev"
JSON = "dev.json"
DB = "dev_databases"

JSON_FILE = "./" + SET + "/" + JSON
DB_DIR = "./" + SET + "/" + DB

dryrun = False

if not os.path.exists(DB_DIR):
    raise ValueError(f"DB_DIR {DB_DIR} does not exist.")
if not os.path.exists(JSON_FILE):
    raise ValueError(f"JSON_FILE {JSON_FILE} does not exist.")

# DEFAULT_MODEL = "gpt-4-turbo-preview"
DEFAULT_MODEL = 'gpt-4-0125-preview'

encoding = tiktoken.get_encoding("cl100k_base")

# %%
def num_tokens_from_messages(messages, tokens_per_message=3, tokens_per_name=1):
    num_tokens = 0
    for message in messages:
        num_tokens += tokens_per_message
        for key, value in message.items():
            num_tokens += len(encoding.encode(value))
            if key == "name":
                num_tokens += tokens_per_name
    num_tokens += 3
    return num_tokens


def get_create_table_and_data(db_path: str, num_rows: int = 5) -> List[str]:
    MAX_TOKENS = 5000
    conn = sqlite3.connect(db_path, timeout=30)
    cursor = conn.cursor()
    while num_rows >= 0:
        # Query the sqlite_master table to get the CREATE TABLE statements
        cursor.execute(
            "SELECT name, sql FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%'"
        )
        tables = cursor.fetchall()

        output_statements = []

        for table_name, create_statement in tables:
            # "INTEGER" -> "INT"
            create_statement = create_statement.replace("INTEGER", "INT")

            # remove comments
            create_statement = re.sub(
                r"--.*$", "", create_statement, flags=re.MULTILINE
            )
            create_statement = "\n".join(
                [line for line in create_statement.split("\n") if line.strip()]
            )

            # Condense whitespace
            create_statement = " ".join(create_statement.split())

            # First, add the create statement
            output_statements.append(create_statement + ";")

            # Fetch sample data
            cursor.execute(f"SELECT * FROM `{table_name}` LIMIT ?", (num_rows,))
            sample_rows = cursor.fetchall()

            # For each row, create an INSERT INTO statement
            for row in sample_rows:
                formatted_values = []
                for idx, value in enumerate(row):
                    if isinstance(value, str):
                        formatted_value = value.replace("\n", " ")
                        formatted_value = formatted_value.replace("'", '"')
                        formatted_value = formatted_value[:100]
                        formatted_values.append(f"'{formatted_value}'")
                    elif value is None:
                        formatted_values.append("NULL")
                    else:
                        formatted_values.append(str(value))
                values_str = ",".join(formatted_values)

                # Check if table_name contains a space or dash and wrap it in double quotes if it does
                if " " in table_name or "-" in table_name:
                    formatted_table_name = f'"{table_name}"'
                else:
                    formatted_table_name = table_name

                insert_statement = (
                    f"INSERT INTO {formatted_table_name} VALUES ({values_str});"
                )
                output_statements.append(insert_statement)

        msgs = [{"role": "user", "content": "\n".join(output_statements)}]
        token_count = num_tokens_from_messages(msgs)

        if token_count < MAX_TOKENS:
            cursor.close()
            conn.close()
            return output_statements#, tables
        elif num_rows > 0:
            num_rows -= 1
            continue
        else:
            final_statements = []
            for statement in output_statements:
                final_statements.append(statement)
                msgs = [{"role": "user", "content": "\n".join(final_statements)}]
                token_count = num_tokens_from_messages(msgs)

                if token_count > MAX_TOKENS:
                    cursor.close()
                    conn.close()
                    final_statements.pop()
                    return final_statements#, tables
    cursor.close()
    conn.close()
    raise ValueError(f"Even with 0 rows, token count is too high!")


def clean_creates(sql_text: str) -> str:
    """While these fields might be useful for some purposes, I've honestly
    needed them so rarely as a data scientist that we are going to exclude them
    """

    def replace_(node: Expression) -> Optional[Expression]:
        if isinstance(
            node,
            (
                expressions.ColumnConstraint,
                expressions.PrimaryKey,
                expressions.Constraint,
            ),
        ):
            return None
        return node

    return str(sqlglot.parse_one(sql_text).transform(replace_))


def hard_replace__clean_creates(sql_text: str):
    """The backticks and double-quotes are always equivalent in bird
    # but sqlglot cannot yet handle the backticks
    """
    try:
        return clean_creates(
            sql_text.replace("`", '"')
            .replace("WITHOUT ROWID", "")
            .replace("on update cascade", "")
            .replace("ON UPDATE CASCADE", "")
            .replace("on delete cascade", "")
            .replace("ON DELETE CASCADE", "")
            .replace("references staff", "")
        )
    except Exception:
        raise


def read_in_all_sqlite_dbs(directory):
    """Read in all the sqlite databases from the bird data"""
    dirs = glob.glob(directory + "/*")
    statements = []
    for d in dirs:
        if os.path.isfile(d):
            continue
        dbname = d.split("/")[-1]
        sqlite_db_path = os.path.join(d, dbname + ".sqlite")
        assert os.path.exists(d), f"DB {d} does not exist!"
        ddl_list = get_create_table_and_data(sqlite_db_path)
        for ddl in ddl_list:
            statements.append((dbname, hard_replace__clean_creates(ddl)))

    return statements


def make_x(tables, db_id, ideal_sql, question):
    """Make the x and y for the training data"""
    return tables, db_id, ideal_sql, question

# %%
df_reference_embeddings = pd.read_csv('BIRD_train_embeddings.csv')
df_reference_embeddings.head()
# Out:
#                                             question  \
# 0  Name movie titles released in year 1945. Sort ...
# 1  State the most popular movie? When was it rele...
# 2  What is the name of the longest movie title? W...
# 3              Name the movie with the most ratings.
# 4  What is the average number of Mubi users who l...
#
#                                           embeddings
# 0  [-0.006165551487356424, 0.0049751438200473785,...
# 1  [-0.02109631896018982, 0.03676282986998558, -0...
# 2  [0.002490998711436987, 0.03317447006702423, -0...
# 3  [-0.04145917296409607, 0.019352909177541733, -...
# 4  [-0.0009301478858105838, -0.012216581963002682...

# %%
import chardet

def read_database_descriptions(dir):
    consolidated_df = pd.DataFrame()
    
    dirs = glob.glob(dir + "/*")

    typo_corrections = {
        'original_column_name': ['original_column_name'],
        'column_description': ['column_description', 'column_desription']  # Add known typos here
    }
    
    for d in dirs:
        files = glob.glob(d + "/database_description/*")
        
        for f in files:
            # print(f)
            # Attempt to detect the file encoding
            with open(f, 'rb') as file:
                raw_data = file.read(10000)  # Read first 10000 bytes to guess encoding
                result = chardet.detect(raw_data)
                encoding = result['encoding']
                
            try:
                # Try reading with the detected encoding
                tmp = pd.read_csv(f, encoding=encoding)
            except UnicodeDecodeError:
                try:
                    # Fallback: Try reading with 'latin1'
                    tmp = pd.read_csv(f, encoding='latin1')
                except UnicodeDecodeError:
                    # Last resort: Ignore errors or replace invalid characters
                    tmp = pd.read_csv(f, encoding=encoding, errors='replace')

            # Attempt to correct column names based on known typos
            for correct, possible_typos in typo_corrections.items():
                found = False
                for typo in possible_typos:
                    if typo in tmp.columns:
                        tmp.rename(columns={typo: correct}, inplace=True)
                        found = True
                        break
                if not found:
                    # If no matching columns are found, create an empty column to maintain structure
                    tmp[correct] = None
            
            # Ensure tmp has the columns expected; if not, they are filled with None
            expected_columns = ['original_column_name', 'column_description']
            for col in expected_columns:
                if col not in tmp.columns:
                    tmp[col] = None
            
            tmp = tmp[expected_columns]
            tmp['table'] = f.split('/')[-1].rstrip('.csv')
            tmp['db_id'] = d.split('/')[-1]
            consolidated_df = pd.concat([consolidated_df, tmp], ignore_index=True)
    
    return consolidated_df

# %%
def format_ddl(ddl_str, column_descriptions):
    formatted_ddls = []

    # Split the ddl_str by "CREATE TABLE"
    create_tables = re.split(r"(?i)CREATE TABLE", ddl_str)

    for ct in create_tables:
        if not ct.strip():
            continue

        # Extract table name from the current CREATE TABLE section
        table_name_match = re.search(r'^\s*("?[\w\s-]+"?|[\w\s-]+)', ct)
        table_name = (
            table_name_match.group(1).strip() if table_name_match else "Unknown Table"
        )

        # Find column descriptions for this table
        table_column_descriptions = column_descriptions[column_descriptions['table'].str.strip('"') == table_name.strip('"')]

        # Split the current section at "INSERT INTO"
        splits = ct.split("INSERT INTO")

        # Extract column names and remove the table name from it
        columns = re.sub(r"^\s*" + re.escape(table_name), "", splits[0]).strip()
        if columns.startswith("(") and columns.endswith(")"):
            columns = columns[1:-1]

        # Process compound foreign keys
        fk_pattern = r"(FOREIGN KEY \([^)]+\) REFERENCES [\w]+ \([^)]+\))"
        foreign_keys = re.findall(fk_pattern, columns, re.DOTALL)  # Use DOTALL to match across newlines
        # Replace newlines in foreign key definitions to ensure they stay on one line and use placeholders for commas
        placeholder_mapping = {}
        for i, fk in enumerate(foreign_keys):
            placeholder = f"__PLACEHOLDER_{i}__"
            corrected_fk_str = re.sub(r"\s*\n\s*", " ", fk)  # Replace newlines and surrounding spaces with a single space
            corrected_fk_str = corrected_fk_str.replace(",", placeholder)  # Temporarily replace commas
            placeholder_mapping[placeholder] = ","
            columns = columns.replace(fk, corrected_fk_str)

        # Process INSERT statements
        if ' ' in table_name or '-' in table_name:   
            cleaned_table_name = table_name
        else:
            cleaned_table_name = table_name.strip('"')
        insert_statements = [
            split.replace(f"{cleaned_table_name} VALUES", "").strip()
            for split in splits[1:]
        ]
        # cast the strings to tuples
        insert_tuples = []
        for statement in insert_statements:
            corrected_statement = statement.replace('NULL', 'None')
            result = ast.literal_eval(corrected_statement)
            if isinstance(result, tuple):
                insert_tuples.append(result)
            else:
                insert_tuples.append((result,))

        columns = " ".join(columns.split())
        pattern = r', UNIQUE \([^)]*\)'
        columns = re.sub(pattern, '', columns)

        # Append column descriptions and example values
        column_lines = columns.split(", ")
        # Restore commas in foreign keys
        for placeholder, comma in placeholder_mapping.items():
            column_lines = [line.replace(placeholder, comma) for line in column_lines]

        for i, line in enumerate(column_lines):
            column_name_match = re.match(r'\s*"?(\w+)"?\s+', line)
            if column_name_match:
                column_name = column_name_match.group(1)
                description = table_column_descriptions.loc[table_column_descriptions['original_column_name'] == column_name, 'column_description'].values
                if description.size > 0 and not pd.isna(description[0]):
                    column_lines[i] += f" -- {description[0]}"

                example_values = ""
                unique_values = set()
                for insert in insert_tuples:
                    if i < len(insert) and not pd.isna(insert[i]):
                        if ',' in str(insert[i]):
                            example_value = json.dumps(str(insert[i]))
                        else:
                            example_value = f"{insert[i]}"
                        if example_value not in unique_values and len(example_values) < 50:
                            unique_values.add(example_value)
                            example_values += example_value + ", "

                
                # Trim the trailing comma and space
                example_values = example_values[:-2]

                if example_values:
                    column_lines[i] += f" -- {example_values}"

        columns_with_descriptions = "\n\t".join(column_lines)

        # Combine the statements for the current table and append to formatted_ddls
        formatted_ddl = (
            table_name
            + " (\n\t"
            + columns_with_descriptions
            + "\n)"
        )
        # if insert_statements:
        #     formatted_ddl += "\n" + "\n".join(insert_statements)

        formatted_ddls.append(formatted_ddl)

    return "\n".join(formatted_ddls)

# %%
ddl_statements = read_in_all_sqlite_dbs(DB_DIR)

df_ddl = pd.DataFrame(ddl_statements)
df_ddl.columns = ["db_id", "ddl"]
df_ddl = df_ddl.groupby("db_id")["ddl"].agg("\n".join).reset_index(name="ddl")

column_descriptions = read_database_descriptions(DB_DIR)
column_descriptions.head()

df_ddl["ddl"] = df_ddl.apply(lambda row: format_ddl(row["ddl"], column_descriptions[column_descriptions['db_id'] == row['db_id']]), axis=1)

df_ddl.head()
# Out:
#                      db_id                                                ddl
# 0       california_schools  frpm (\n\tCDSCode TEXT -- CDSCode -- 011001701...
# 1               card_games  "cards" (\n\tid INT -- 1, 2, 3, 4, 5\n\tartist...
# 2       codebase_community  badges (\n\tId INT -- 1, 2, 3, 4, 5\n\tUserId ...
# 3  debit_card_specializing  customers (\n\tCustomerID INT -- 3, 5, 6, 7, 9...
# 4      european_football_2  "Player_Attributes" (\n\t"id" INT -- 1, 2, 3, ...

# %%
reference_ddl_statements = read_in_all_sqlite_dbs(REFERENCE_DB_DIR)

df_reference_ddl = pd.DataFrame(reference_ddl_statements)
df_reference_ddl.columns = ["db_id", "ddl"]
df_reference_ddl = df_reference_ddl.groupby("db_id")["ddl"].agg("\n".join).reset_index(name="ddl")

reference_column_descriptions = read_database_descriptions(REFERENCE_DB_DIR)
reference_column_descriptions.head()

df_reference_ddl["ddl"] = df_reference_ddl.apply(lambda row: format_ddl(row["ddl"], reference_column_descriptions[reference_column_descriptions['db_id'] == row['db_id']]), axis=1)

# %%
for ddl in df_reference_ddl["ddl"]:
    if 'SpecialOfferID' in ddl:
        print(ddl)
# Out:
# CountryRegion (
# 	CountryRegionCode TEXT -- The unique id number identifying Country Region ISO standard code for countries and regions.
# 	Name TEXT -- Country or region name.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# Culture (
# 	CultureID TEXT -- The unique id string identifying the language in which AdventrueWorks data is stored.
# 	Name TEXT -- Name of the language.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# Currency (
# 	CurrencyCode TEXT -- The unique id string identifying the currency.
# 	Name TEXT -- Currency name.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# CountryRegionCurrency (
# 	CountryRegionCode TEXT -- The id number identifying Country Region ISO standard code for countries and regions.
# 	CurrencyCode TEXT -- ISO standard currency code.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (CountryRegionCode) REFERENCES CountryRegion (CountryRegionCode)
# 	FOREIGN KEY (CurrencyCode) REFERENCES Currency (CurrencyCode)
# )
# Person (
# 	BusinessEntityID INT -- The unique id number identifying the person.
# 	PersonType TEXT -- The type of person.
# 	NameStyle INT -- Name Style.
# 	Title TEXT -- A courtesy title.
# 	FirstName TEXT -- First name of the person.
# 	MiddleName TEXT -- Middle name or middle initial of the person.
# 	LastName TEXT -- Last name of the person.
# 	Suffix TEXT -- Surname suffix.
# 	EmailPromotion INT -- Email Promotion.
# 	AdditionalContactInfo TEXT -- Additional contact information about the person stored in xml format.
# 	Demographics TEXT -- Personal information such as hobbies, and income collected from online shoppers. Used for sales analysis.
# 	rowguid TEXT -- Uniquely identifying the record. Used to support a merge replication sample.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (BusinessEntityID) REFERENCES BusinessEntity (BusinessEntityID)
# )
# BusinessEntityContact (
# 	BusinessEntityID INT -- The id number identifying the Business Entity ID.
# 	PersonID INT -- The id number identifying the Person ID.
# 	ContactTypeID INT -- The id number identifying the contact type ID.
# 	rowguid TEXT -- Uniquely identifying the record. Used to support a merge replication sample.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (BusinessEntityID) REFERENCES BusinessEntity (BusinessEntityID)
# 	FOREIGN KEY (ContactTypeID) REFERENCES ContactType (ContactTypeID)
# 	FOREIGN KEY (PersonID) REFERENCES Person (BusinessEntityID)
# )
# EmailAddress (
# 	BusinessEntityID INT
# 	EmailAddressID INT
# 	EmailAddress TEXT
# 	rowguid TEXT
# 	ModifiedDate DATETIME
# 	FOREIGN KEY (BusinessEntityID) REFERENCES Person (BusinessEntityID)
# )
# Employee (
# 	BusinessEntityID INT -- The id number identifying the employee.
# 	NationalIDNumber TEXT -- The national identification number such as a social security number.
# 	LoginID TEXT -- Network login.
# 	OrganizationNode TEXT -- Where the employee is located in corporate hierarchy.
# 	OrganizationLevel INT -- The depth of the employee in the corporate hierarchy.
# 	JobTitle TEXT -- Work title such as Buyer or Sales Representative.
# 	BirthDate DATE -- Date of birth.
# 	MaritalStatus TEXT -- Whether this employee is married or not.
# 	Gender TEXT -- The gender of this employee.
# 	HireDate DATE -- The employee was hired on this date.
# 	SalariedFlag INT -- Job classification.
# 	VacationHours INT -- The number of available vacation hours.
# 	SickLeaveHours INT -- The number of available sick leave hours.
# 	CurrentFlag INT -- Whether this employee is active or not
# 	rowguid TEXT -- Uniquely identifying the record. Used to support a merge replication sample.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (BusinessEntityID) REFERENCES Person (BusinessEntityID)
# )
# Password (
# 	BusinessEntityID INT -- The unique id number identifying the person.
# 	PasswordHash TEXT -- Password for the e-mail account.
# 	PasswordSalt TEXT -- Random value concatenated with the password string before the password is hashed.
# 	rowguid TEXT -- Uniquely identifying the record. Used to support a merge replication sample.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (BusinessEntityID) REFERENCES Person (BusinessEntityID)
# )
# PersonCreditCard (
# 	BusinessEntityID INT -- The id number identifying the person.
# 	CreditCardID INT -- Credit card identification number.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (CreditCardID) REFERENCES CreditCard (CreditCardID)
# 	FOREIGN KEY (BusinessEntityID) REFERENCES Person (BusinessEntityID)
# )
# ProductCategory (
# 	ProductCategoryID INT -- The unique id number identifying the product category.
# 	Name TEXT -- Category description
# 	rowguid TEXT -- Uniquely identifying the record. Used to support a merge replication sample.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# ProductDescription (
# 	ProductDescriptionID INT -- The unique id number identifying the product description.
# 	Description TEXT -- Description of the product.
# 	rowguid TEXT -- Uniquely identifying the record. Used to support a merge replication sample.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# ProductModel (
# 	ProductModelID INT -- The unique id number identifying the product model.
# 	Name TEXT -- Product model description.
# 	CatalogDescription TEXT -- Detailed product catalog information in xml format.
# 	Instructions TEXT -- Manufacturing instructions in xml format.
# 	rowguid TEXT -- Uniquely identifying the record. Used to support a merge replication sample.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# ProductModelProductDescriptionCulture (
# 	ProductModelID INT -- The id number identifying the product model.
# 	ProductDescriptionID INT -- Product description identification number.
# 	CultureID TEXT -- Culture identification number.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (ProductModelID) REFERENCES ProductModel (ProductModelID)
# 	FOREIGN KEY (ProductDescriptionID) REFERENCES ProductDescription (ProductDescriptionID)
# 	FOREIGN KEY (CultureID) REFERENCES Culture (CultureID)
# )
# ProductPhoto (
# 	ProductPhotoID INT -- unique id number identifying the products
# 	ThumbNailPhoto VARBINARY -- Small image of the product.
# 	ThumbnailPhotoFileName TEXT -- Small image file name
# 	LargePhoto VARBINARY -- Large image of the product.
# 	LargePhotoFileName TEXT -- Large image file name.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# ProductSubcategory (
# 	ProductSubcategoryID INT -- Unique id number identifying the subcategory of products.
# 	ProductCategoryID INT -- Product category identification number.
# 	Name TEXT -- Subcategory description.
# 	rowguid TEXT -- Uniquely identifying the record. Used to support a merge replication sample.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (ProductCategoryID) REFERENCES ProductCategory (ProductCategoryID)
# )
# SalesReason (
# 	SalesReasonID INT -- The unique number identifying SalesReason records.
# 	Name TEXT -- Sales reason description
# 	ReasonType TEXT -- Category the sales reason belongs to.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# SalesTerritory (
# 	TerritoryID INT -- The unique id number for SalesTerritory records.
# 	Name TEXT -- Sales territory description.
# 	CountryRegionCode TEXT -- ISO standard country or region code.
# 	"Group" TEXT -- Geographic area to which the sales territory belong.
# 	SalesYTD FLOAT -- Sales in the territory year to date.
# 	SalesLastYear FLOAT -- Sales in the territory the previous year.
# 	CostYTD FLOAT -- Business costs in the territory year to date.
# 	CostLastYear FLOAT -- Business costs in the territory the previous year.
# 	rowguid TEXT -- Uniquely identifying the record. Used to support a merge replication sample.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (CountryRegionCode) REFERENCES CountryRegion (CountryRegionCode)
# )
# SalesPerson (
# 	BusinessEntityID INT -- The unique id number identifying the business entity.
# 	TerritoryID INT -- Territory currently assigned to.
# 	SalesQuota FLOAT -- Projected yearly sales
# 	Bonus FLOAT -- Bonus due if quota is met.
# 	CommissionPct FLOAT
# 	SalesYTD FLOAT -- Sales total year to date
# 	SalesLastYear FLOAT -- Sales total of previous year.
# 	rowguid TEXT -- Uniquely identifying the record. Used to support a merge replication sample.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (BusinessEntityID) REFERENCES Employee (BusinessEntityID)
# 	FOREIGN KEY (TerritoryID) REFERENCES SalesTerritory (TerritoryID)
# )
# SalesPersonQuotaHistory (
# 	BusinessEntityID INT -- Sales person identification number
# 	QuotaDate DATETIME -- Sales quota date
# 	SalesQuota FLOAT -- Sales quota amount
# 	rowguid TEXT -- Uniquely identifying the record. Used to support a merge replication sample.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (BusinessEntityID) REFERENCES SalesPerson (BusinessEntityID)
# )
# SalesTerritoryHistory (
# 	BusinessEntityID INT -- The sales representative.
# 	TerritoryID INT -- Territory identification number.
# 	StartDate DATETIME -- Date the sales representive started work in the territory.
# 	EndDate DATETIME -- Date the sales representative left work in the territory.
# 	rowguid TEXT -- Uniquely identifying the record. Used to support a merge replication sample.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (BusinessEntityID) REFERENCES SalesPerson (BusinessEntityID)
# 	FOREIGN KEY (TerritoryID) REFERENCES SalesTerritory (TerritoryID)
# )
# ScrapReason (
# 	ScrapReasonID INT -- The unique number identifying for ScrapReason records.
# 	Name TEXT -- Failure description.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# Shift (
# 	ShiftID INT -- The unique number identifying the shift.
# 	Name TEXT -- Shift description.
# 	StartTime TEXT -- Shift start time.
# 	EndTime TEXT -- Shift end time.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# ShipMethod (
# 	ShipMethodID INT -- The unique number for ShipMethod records.
# 	Name TEXT -- Shipping company name.
# 	ShipBase FLOAT -- Minimum shipping charge.
# 	ShipRate FLOAT -- Shipping charge per pound.
# 	rowguid TEXT -- Uniquely identifying the record. Used to support a merge replication sample.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# SpecialOffer (
# 	SpecialOfferID INT -- The unique id number identifying the special offer.
# 	Description TEXT -- Discount description.
# 	DiscountPct FLOAT -- Discount percentage.
# 	Type TEXT -- Discount type category.
# 	Category TEXT -- Group the discount applies to such as Reseller or Customer.
# 	StartDate DATETIME -- Discount start date.
# 	EndDate DATETIME -- Discount end date.
# 	MinQty INT -- Minimum discount percent allowed.
# 	MaxQty INT -- Maximum discount percent allowed.
# 	rowguid TEXT -- Uniquely identifying the record. Used to support a merge replication sample.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# BusinessEntityAddress (
# 	BusinessEntityID INT
# 	AddressID INT
# 	AddressTypeID INT
# 	rowguid TEXT
# 	ModifiedDate DATETIME
# 	FOREIGN KEY (AddressID) REFERENCES Address (AddressID)
# 	FOREIGN KEY (AddressTypeID) REFERENCES AddressType (AddressTypeID)
# 	FOREIGN KEY (BusinessEntityID) REFERENCES BusinessEntity (BusinessEntityID)
# )
# SalesTaxRate (
# 	SalesTaxRateID INT -- Unique id number identifying sales tax records.
# 	StateProvinceID INT -- id number identifying state province.
# 	TaxType INT -- Tax Type
# 	TaxRate FLOAT -- Tax rate amount
# 	Name TEXT -- Tax rate description
# 	rowguid TEXT -- Uniquely identifying the record. Used to support a merge replication sample.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (StateProvinceID) REFERENCES StateProvince (StateProvinceID)
# )
# Store (
# 	BusinessEntityID INT -- The unique number identifying business entity.
# 	Name TEXT -- Name of the store.
# 	SalesPersonID INT -- ID of the sales person assigned to the customer.
# 	Demographics TEXT -- Demographic information about the store such as the number of employees, annual sales and store type.
# 	rowguid TEXT -- Uniquely identifying the record. Used to support a merge replication sample.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (BusinessEntityID) REFERENCES BusinessEntity (BusinessEntityID)
# 	FOREIGN KEY (SalesPersonID) REFERENCES SalesPerson (BusinessEntityID)
# )
# SalesOrderHeaderSalesReason (
# 	SalesOrderID INT -- The id number of sales order.
# 	SalesReasonID INT -- The id number for sales reasons.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (SalesOrderID) REFERENCES SalesOrderHeader (SalesOrderID)
# 	FOREIGN KEY (SalesReasonID) REFERENCES SalesReason (SalesReasonID)
# )
# TransactionHistoryArchive (
# 	TransactionID INT -- The unique id number identifying TransactionHistory records.
# 	ProductID INT -- Product identification number.
# 	ReferenceOrderID INT -- Purchase order, sales order, or work order identification number.
# 	ReferenceOrderLineID INT -- Line number associated with the purchase order, sales order, or work order.
# 	TransactionDate DATETIME -- Date and time of the transaction.
# 	TransactionType TEXT -- Type of transaction records.
# 	Quantity INT -- Product quantity.
# 	ActualCost FLOAT -- Product cost.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# UnitMeasure (
# 	UnitMeasureCode TEXT -- The unique identifying numbers for measure.
# 	Name TEXT -- Unit of measure description.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# ProductCostHistory (
# 	ProductID INT -- The id number identifying the product.
# 	StartDate DATE -- Product cost start date
# 	EndDate DATE -- Product cost end date
# 	StandardCost FLOAT -- Standard cost of the product.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (ProductID) REFERENCES Product (ProductID)
# )
# ProductDocument (
# 	ProductID INT -- The id number identifying the product.
# 	DocumentNode TEXT -- The hierarchy id number identifying the Document node.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (ProductID) REFERENCES Product (ProductID)
# 	FOREIGN KEY (DocumentNode) REFERENCES Document (DocumentNode)
# )
# ProductInventory (
# 	ProductID INT -- Product identification number.
# 	LocationID INT -- Inventory location identification number.
# 	Shelf TEXT -- Storage compartment within an inventory location.
# 	Bin INT -- Storage container on a shelf in an inventory location.
# 	Quantity INT -- Quantity of products in the inventory location.
# 	rowguid TEXT -- Uniquely identifying the record. Used to support a merge replication sample.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (ProductID) REFERENCES Product (ProductID)
# 	FOREIGN KEY (LocationID) REFERENCES Location (LocationID)
# )
# ProductProductPhoto (
# 	ProductID INT -- Product identification number.
# 	ProductPhotoID INT -- Product photo identification number.
# 	"Primary" INT -- Whether this photo is the principal image or not.
# 	ModifiedDate DATETIME
# 	FOREIGN KEY (ProductID) REFERENCES Product (ProductID)
# 	FOREIGN KEY (ProductPhotoID) REFERENCES ProductPhoto (ProductPhotoID)
# )
# ProductReview (
# 	ProductReviewID INT -- The unique id numbers identifying product reviews.
# 	ProductID INT -- Product identification number.
# 	ReviewerName TEXT -- The name of reviewer.
# 	ReviewDate DATETIME -- Date review was submitted.
# 	EmailAddress TEXT -- Reviewer's e-mail address.
# 	Rating INT -- Product rating given by the reviewer.
# 	Comments TEXT
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (ProductID) REFERENCES Product (ProductID)
# )
# ShoppingCartItem (
# 	ShoppingCartItemID INT -- The unique id number identifying the shopping cart item records.
# 	ShoppingCartID TEXT -- Shopping cart identification number.
# 	Quantity INT -- Product quantity ordered.
# 	ProductID INT -- Product ordered.
# 	DateCreated DATETIME -- Date the time the record was created.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (ProductID) REFERENCES Product (ProductID)
# )
# SpecialOfferProduct (
# 	SpecialOfferID INT -- The id for SpecialOfferProduct records
# 	ProductID INT -- Product identification number.
# 	rowguid TEXT -- Uniquely identifying the record. Used to support a merge replication sample.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (SpecialOfferID) REFERENCES SpecialOffer (SpecialOfferID)
# 	FOREIGN KEY (ProductID) REFERENCES Product (ProductID)
# )
# SalesOrderDetail (
# 	SalesOrderID INT
# 	SalesOrderDetailID INT
# 	CarrierTrackingNumber TEXT
# 	OrderQty INT
# 	ProductID INT
# 	SpecialOfferID INT
# 	UnitPrice FLOAT
# 	UnitPriceDiscount FLOAT
# 	LineTotal FLOAT
# 	rowguid TEXT
# 	ModifiedDate DATETIME -- modified date
# 	FOREIGN KEY (SalesOrderID) REFERENCES SalesOrderHeader (SalesOrderID)
# 	FOREIGN KEY (SpecialOfferID, ProductID) REFERENCES SpecialOfferProduct (SpecialOfferID, ProductID)
# )
# TransactionHistory (
# 	TransactionID INT -- The unique id number identifying TransactionHistory records.
# 	ProductID INT -- Product identification number.
# 	ReferenceOrderID INT -- Purchase order, sales order, or work order identification number.
# 	ReferenceOrderLineID INT -- Line number associated with the purchase order, sales order, or work order.
# 	TransactionDate DATETIME -- Date and time of the transaction.
# 	TransactionType TEXT -- Type of transaction records.
# 	Quantity INT -- Product quantity.
# 	ActualCost FLOAT -- Product cost.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (ProductID) REFERENCES Product (ProductID)
# )
# Vendor (
# 	BusinessEntityID INT -- The unique number identifying Vendor records.
# 	AccountNumber TEXT -- Vendor account (identification) number.
# 	Name TEXT -- Company name.
# 	CreditRating INT -- Rating of credit.
# 	PreferredVendorStatus INT -- Preferred Vendor Status
# 	ActiveFlag INT -- Vendor URL
# 	PurchasingWebServiceURL TEXT -- Purchasing Web Service URL
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (BusinessEntityID) REFERENCES BusinessEntity (BusinessEntityID)
# )
# ProductVendor (
# 	ProductID INT -- The id number identifying the products.
# 	BusinessEntityID INT -- The id number identifying the business entities.
# 	AverageLeadTime INT -- The average span of time between placing an order with the vendor and receiving the purchased product.
# 	StandardPrice FLOAT -- The vendor's usual selling price.
# 	LastReceiptCost FLOAT -- The selling price when last purchased.
# 	LastReceiptDate DATETIME -- Date the product was last received by the vendor.
# 	MinOrderQty INT -- The maximum quantity that should be ordered.
# 	MaxOrderQty INT -- The minimum quantity that should be ordered.
# 	OnOrderQty INT -- The quantity currently on order.
# 	UnitMeasureCode TEXT -- The product's unit of measure.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (ProductID) REFERENCES Product (ProductID)
# 	FOREIGN KEY (BusinessEntityID) REFERENCES Vendor (BusinessEntityID)
# 	FOREIGN KEY (UnitMeasureCode) REFERENCES UnitMeasure (UnitMeasureCode)
# )
# PurchaseOrderHeader (
# 	PurchaseOrderID INT -- The unique id number identifying purchase order.
# 	RevisionNumber INT -- Incremental number to track changes to the purchase order over time.
# 	Status INT -- Order current status.
# 	EmployeeID INT -- Employee who created the purchase order.
# 	VendorID INT -- Vendor with whom the purchase order is placed.
# 	ShipMethodID INT -- Shipping method
# 	OrderDate DATETIME -- Purchase order creation date
# 	ShipDate DATETIME -- Estimated shipment date from the vendor.
# 	SubTotal FLOAT -- Purchase order subtotal
# 	TaxAmt FLOAT -- Tax amount
# 	Freight FLOAT -- Shipping cost
# 	TotalDue FLOAT -- Total due to vendor
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (EmployeeID) REFERENCES Employee (BusinessEntityID)
# 	FOREIGN KEY (VendorID) REFERENCES Vendor (BusinessEntityID)
# 	FOREIGN KEY (ShipMethodID) REFERENCES ShipMethod (ShipMethodID)
# )
# PurchaseOrderDetail (
# 	PurchaseOrderID INT -- Purchase order number.
# 	PurchaseOrderDetailID INT -- Unique purchase detail order.
# 	DueDate DATETIME -- Date the product is expected to be received.
# 	OrderQty INT -- Quantity ordered.
# 	ProductID INT -- The id number identifying products.
# 	UnitPrice FLOAT -- Vendor's selling price of a single product.
# 	LineTotal FLOAT -- Per product subtotal
# 	ReceivedQty FLOAT -- Quantity actually received from the vendor.
# 	RejectedQty FLOAT
# 	StockedQty FLOAT
# 	ModifiedDate DATETIME
# 	FOREIGN KEY (PurchaseOrderID) REFERENCES PurchaseOrderHeader (PurchaseOrderID)
# 	FOREIGN KEY (ProductID) REFERENCES Product (ProductID)
# )
# WorkOrder (
# 	WorkOrderID INT -- The unique id number identifying work order.
# 	ProductID INT -- Product identification number.
# 	OrderQty INT -- Product quantity to build.
# 	StockedQty INT -- Quantity built and put in inventory.
# 	ScrappedQty INT -- Quantity that failed inspection.
# 	StartDate DATETIME -- Work order start date.
# 	EndDate DATETIME -- Work order end date.
# 	DueDate DATETIME -- Work order due date.
# 	ScrapReasonID INT -- Reason for inspection failure.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (ProductID) REFERENCES Product (ProductID)
# 	FOREIGN KEY (ScrapReasonID) REFERENCES ScrapReason (ScrapReasonID)
# )
# WorkOrderRouting (
# 	WorkOrderID INT -- The id number of work order.
# 	ProductID INT -- The id number identifying products.
# 	OperationSequence INT -- Indicates the manufacturing process sequence.
# 	LocationID INT -- Manufacturing location where the part is processed.
# 	ScheduledStartDate DATETIME -- Planned manufacturing start date.
# 	ScheduledEndDate DATETIME -- Planned manufacturing end date.
# 	ActualStartDate DATETIME -- Actual start date.
# 	ActualEndDate DATETIME -- Actual end date.
# 	ActualResourceHrs FLOAT -- Number of manufacturing hours used.
# 	PlannedCost FLOAT -- Estimated manufacturing cost.
# 	ActualCost FLOAT -- Actual manufacturing cost.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (WorkOrderID) REFERENCES WorkOrder (WorkOrderID)
# 	FOREIGN KEY (LocationID) REFERENCES Location (LocationID)
# )
# Customer (
# 	CustomerID INT -- The unique id number identifying the customer.
# 	PersonID INT -- The id number identifying the person.
# 	StoreID INT -- The id number identifying the store / bussiness entity.
# 	TerritoryID INT -- ID of the territory in which the customer is located.
# 	AccountNumber TEXT -- Unique number identifying the customer assigned by the accounting system.
# 	rowguid TEXT -- Uniquely identifying the record. Used to support a merge replication sample.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (PersonID) REFERENCES Person (BusinessEntityID)
# 	FOREIGN KEY (TerritoryID) REFERENCES SalesTerritory (TerritoryID)
# 	FOREIGN KEY (StoreID) REFERENCES Store (BusinessEntityID)
# )
# ProductListPriceHistory (
# 	ProductID INT -- Product identification number.
# 	StartDate DATE -- List price start date.
# 	EndDate DATE -- List price end date.
# 	ListPrice FLOAT -- Product list price.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# 	FOREIGN KEY (ProductID) REFERENCES Product (ProductID)
# )
# "Address" (
# 	AddressID INT
# 	AddressLine1 TEXT
# 	AddressLine2 TEXT
# 	City TEXT
# 	StateProvinceID INT
# 	PostalCode TEXT
# 	SpatialLocation TEXT
# 	rowguid TEXT
# 	ModifiedDate DATETIME
# )
# "AddressType" (
# 	AddressTypeID INT -- Unique numbers identifying address type records.
# 	Name TEXT -- Address type description.
# 	rowguid TEXT -- Uniquely identifying the record. Used to support a merge replication sample.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# "BillOfMaterials" (
# 	BillOfMaterialsID INT
# 	ProductAssemblyID INT
# 	ComponentID INT
# 	StartDate DATETIME
# 	EndDate DATETIME
# 	UnitMeasureCode TEXT
# 	BOMLevel INT
# 	PerAssemblyQty FLOAT
# 	ModifiedDate DATETIME
# )
# "BusinessEntity" (
# 	BusinessEntityID INT -- Unique number of identifying business entity.
# 	rowguid TEXT -- Uniquely identifying the record. Used to support a merge replication sample.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# "ContactType" (
# 	ContactTypeID INT -- The unique id number identifying the contact type ID.
# 	Name TEXT -- Contact type description.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# "CurrencyRate" (
# 	CurrencyRateID INT -- The unique id number identifying the currency rate record.
# 	CurrencyRateDate DATETIME -- Date and time the exchange rate was obtained.
# 	FromCurrencyCode TEXT -- Exchange rate was converted from this currency code.
# 	ToCurrencyCode TEXT -- Exchange rate was converted to this currency code.
# 	AverageRate FLOAT -- Average exchange rate for the day.
# 	EndOfDayRate FLOAT -- Final exchange rate for the day.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# "Department" (
# 	DepartmentID INT -- The unique id number identifying the department.
# 	Name TEXT -- Name of the department.
# 	GroupName TEXT -- Name of the group to which the department belongs.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# "EmployeeDepartmentHistory" (
# 	BusinessEntityID INT -- Employee identification number.
# 	DepartmentID INT -- Department in which the employee worked including currently.
# 	ShiftID INT -- Identifies which 8-hour shift the employee works.
# 	StartDate DATE -- Date the employee started working in the department.
# 	EndDate DATE -- Date the employee ended working in the department.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# "EmployeePayHistory" (
# 	BusinessEntityID INT -- Employee identification number.
# 	RateChangeDate DATETIME -- Date the change in pay is effective.
# 	Rate FLOAT -- Salary hourly rate.
# 	PayFrequency INT -- Pay Frequency.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# "JobCandidate" (
# 	JobCandidateID INT -- The unique id number identifying the job candidates.
# 	BusinessEntityID INT -- Employee identification number if applicant was hired.
# 	Resume TEXT -- Résumé in XML format.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# "Location" (
# 	LocationID INT -- The unique id number identifying the job candidates.
# 	Name TEXT -- Location description.
# 	CostRate FLOAT -- Standard hourly cost of the manufacturing location.
# 	Availability FLOAT -- Work capacity (in hours) of the manufacturing location.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# "PhoneNumberType" (
# 	PhoneNumberTypeID INT -- The id number identifying the telephone number type records.
# 	Name TEXT -- Name of the telephone number type.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# "Product" (
# 	ProductID INT -- The unique id number identifying the product.
# 	Name TEXT -- Name of the product.
# 	ProductNumber TEXT -- The unique product identification number.
# 	MakeFlag INT -- The source of product make.
# 	FinishedGoodsFlag INT -- Whether the product is salable or not.
# 	Color TEXT -- Color
# 	SafetyStockLevel INT -- The minimum inventory quantity.
# 	ReorderPoint INT -- Inventory level that triggers a purchase order or work order.
# 	StandardCost FLOAT -- Standard cost of the product.
# 	ListPrice FLOAT -- Selling price
# 	Size TEXT -- Product size
# 	SizeUnitMeasureCode TEXT -- Unit of measure for Size column.
# 	WeightUnitMeasureCode TEXT -- Unit of measure for Weight column.
# 	Weight FLOAT -- Product weight
# 	DaysToManufacture INT -- Number of days required to manufacture the product.
# 	ProductLine TEXT -- Product Routine
# 	Class TEXT -- Product quality class
# 	Style TEXT -- Style
# 	ProductSubcategoryID INT -- Product is a member of this product subcategory.
# 	ProductModelID INT -- Product is a member of this product model.
# 	SellStartDate DATETIME -- Date the product was available for sale.
# 	SellEndDate DATETIME -- Date the product was no longer available for sale.
# 	DiscontinuedDate DATETIME -- Date the product was discontinued.
# 	rowguid TEXT -- Uniquely identifying the record. Used to support a merge replication sample.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# "Document" (
# 	DocumentNode TEXT -- The unique hierarchy id identifying the document nodes.
# 	DocumentLevel INT -- Depth in the document hierarchy.
# 	Title TEXT -- Title of the document.
# 	Owner INT -- Employee who controls the document.
# 	FolderFlag INT -- The type of the folders.
# 	FileName TEXT -- Uniquely identifying the record. Used to support a merge replication sample.
# 	FileExtension TEXT -- File extension indicating the document type.
# 	Revision TEXT -- Revision number of the document.
# 	ChangeNumber INT -- Engineering change approval number.
# 	Status INT -- Status of document processing.
# 	DocumentSummary TEXT -- Document abstract.
# 	Document VARBINARY -- Complete document.
# 	rowguid TEXT -- Uniquely identifying the record. Used to support a merge replication sample.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# "StateProvince" (
# 	StateProvinceID INT -- The unique number for StateProvince records.
# 	StateProvinceCode TEXT -- ISO standard state or province code.
# 	CountryRegionCode TEXT -- ISO standard country or region code.
# 	IsOnlyStateProvinceFlag INT
# 	Name TEXT -- State or province description.
# 	TerritoryID INT -- ID of the territory in which the state or province is located.
# 	rowguid TEXT -- Uniquely identifying the record. Used to support a merge replication sample.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# "CreditCard" (
# 	CreditCardID INT -- The unique id number identifying the credit card.
# 	CardType TEXT -- Credit card name.
# 	CardNumber TEXT -- Credit card number.
# 	ExpMonth INT -- Credit card expiration month.
# 	ExpYear INT -- Credit card expiration year.
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )
# "SalesOrderHeader" (
# 	SalesOrderID INT -- The id number of sales order.
# 	RevisionNumber INT
# 	OrderDate DATETIME
# 	DueDate DATETIME
# 	ShipDate DATETIME -- Estimated shipment date from the vendor
# 	Status INT -- Order current status
# 	OnlineOrderFlag INT
# 	SalesOrderNumber TEXT
# 	PurchaseOrderNumber TEXT
# 	AccountNumber TEXT
# 	CustomerID INT
# 	SalesPersonID INT
# 	TerritoryID INT
# 	BillToAddressID INT
# 	ShipToAddressID INT
# 	ShipMethodID INT -- Shipping method
# 	CreditCardID INT
# 	CreditCardApprovalCode TEXT
# 	CurrencyRateID INT
# 	SubTotal FLOAT
# 	TaxAmt FLOAT -- Tax amount
# 	Freight FLOAT -- Shipping cost
# 	TotalDue FLOAT -- Total due to vendor
# 	Comment TEXT
# 	rowguid TEXT
# 	ModifiedDate DATETIME -- Date and time the record was last updated.
# )

# %%
df_reference_questions = pd.read_json(REFERENCE_JSON)

df_reference_questions = pd.merge(df_reference_questions, df_reference_embeddings, on='question')
df_reference_questions = pd.merge(df_reference_questions, df_reference_ddl, on='db_id')

df_reference_questions['user_prompt'] = df_reference_questions.apply(lambda x: x["ddl"] 
                                                                             + "\n\n" 
                                                                             + x["question"] 
                                                                             + ("\n" + x["evidence"] if x["evidence"] else ""), axis=1)

df_reference_questions.head()
# Out:
#             db_id                                           question  \
# 0  movie_platform  Name movie titles released in year 1945. Sort ...
# 1  movie_platform  State the most popular movie? When was it rele...
# 2  movie_platform  What is the name of the longest movie title? W...
# 3  movie_platform              Name the movie with the most ratings.
# 4  movie_platform  What is the average number of Mubi users who l...
#
#                                             evidence  \
# 0  released in the year 1945 refers to movie_rele...
# 1  most popular movie refers to MAX(movie_popular...
# 2  longest movie title refers to MAX(LENGTH(movie...
# 3  movie with the most rating refers to MAX(SUM(r...
# 4  average = AVG(movie_popularity); number of Mub...
#
#                                                  SQL  \
# 0  SELECT movie_title FROM movies WHERE movie_rel...
# 1  SELECT movie_title, movie_release_year, direct...
# 2  SELECT movie_title, movie_release_year FROM mo...
# 3  SELECT movie_title FROM movies GROUP BY movie_...
# 4  SELECT AVG(movie_popularity) FROM movies WHERE...
#
#                                           embeddings  \
# 0  [-0.006165551487356424, 0.0049751438200473785,...
# 1  [-0.02109631896018982, 0.03676282986998558, -0...
# 2  [0.002490998711436987, 0.03317447006702423, -0...
# 3  [-0.04145917296409607, 0.019352909177541733, -...
# 4  [-0.0009301478858105838, -0.012216581963002682...
#
#                                                  ddl  \
# 0  "lists" (\n\tuser_id INT -- 88260493, 45204418...
# 1  "lists" (\n\tuser_id INT -- 88260493, 45204418...
# 2  "lists" (\n\tuser_id INT -- 88260493, 45204418...
# 3  "lists" (\n\tuser_id INT -- 88260493, 45204418...
# 4  "lists" (\n\tuser_id INT -- 88260493, 45204418...
#
#                                          user_prompt
# 0  "lists" (\n\tuser_id INT -- 88260493, 45204418...
# 1  "lists" (\n\tuser_id INT -- 88260493, 45204418...
# 2  "lists" (\n\tuser_id INT -- 88260493, 45204418...
# 3  "lists" (\n\tuser_id INT -- 88260493, 45204418...
# 4  "lists" (\n\tuser_id INT -- 88260493, 45204418...

# %%
df_question = pd.read_json(JSON_FILE)
joined_df = pd.merge(df_question, df_ddl, on=["db_id"])

joined_df.head()
# Out:
#    question_id               db_id  \
# 0            0  california_schools
# 1            1  california_schools
# 2            2  california_schools
# 3            3  california_schools
# 4            4  california_schools
#
#                                             question  \
# 0  What is the highest eligible free rate for K-1...
# 1  Please list the lowest three eligible free rat...
# 2  Please list the zip code of all the charter sc...
# 3  What is the unabbreviated mailing address of t...
# 4  Please list the phone numbers of the direct ch...
#
#                                             evidence  \
# 0  Eligible free rate for K-12 = `Free Meal Count...
# 1  Eligible free rates for students aged 5-17 = `...
# 2  Charter schools refers to `Charter School (Y/N...
# 3
# 4  Charter schools refers to `Charter School (Y/N...
#
#                                                  SQL difficulty  \
# 0  SELECT `Free Meal Count (K-12)` / `Enrollment ...     simple
# 1  SELECT `Free Meal Count (Ages 5-17)` / `Enroll...   moderate
# 2  SELECT T2.Zip FROM frpm AS T1 INNER JOIN schoo...     simple
# 3  SELECT T2.MailStreet FROM frpm AS T1 INNER JOI...     simple
# 4  SELECT T2.Phone FROM frpm AS T1 INNER JOIN sch...   moderate
#
#                                                  ddl
# 0  frpm (\n\tCDSCode TEXT -- CDSCode -- 011001701...
# 1  frpm (\n\tCDSCode TEXT -- CDSCode -- 011001701...
# 2  frpm (\n\tCDSCode TEXT -- CDSCode -- 011001701...
# 3  frpm (\n\tCDSCode TEXT -- CDSCode -- 011001701...
# 4  frpm (\n\tCDSCode TEXT -- CDSCode -- 011001701...

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

def find_similar_questions(df_questions, df_reference_questions, num_questions = 3):
    # Convert string representations of embeddings back to numpy arrays
    embeddings_reference = np.array([np.array(ast.literal_eval(emb)) for emb in df_reference_questions['embeddings']])
    embeddings_questions = np.array(df_questions['embeddings'].tolist())

    similarities = cosine_similarity(embeddings_questions, embeddings_reference)
    similar_questions = {}

    for index, row in df_questions.iterrows():
        current_db_id = row['db_id']
        # similarities[index, index] = -np.inf  # Exclude the current question

        # Sort the indexes of other questions based on similarity scores
        sorted_indices = np.argsort(similarities[index])[::-1]
        filtered_indices = []
        seen_db_ids = {current_db_id}

        for i in sorted_indices:
            if len(filtered_indices) >= num_questions:
                break  # Stop when we have found enough questions

            candidate_db_id = df_reference_questions.iloc[i]['db_id']
            if candidate_db_id not in seen_db_ids:
                seen_db_ids.add(candidate_db_id)
                filtered_indices.append(i)

        similar_questions[index] = filtered_indices

    return similar_questions

# %%
def get_embeddings(df, column_to_embed):
    embeddings = []
    for text in df[column_to_embed]:
        retries = 0
        while retries < 3:
            try:
                response = openai.embeddings.create(input=text, model="text-embedding-3-large")
                embedding = response.data[0].embedding
                embeddings.append(embedding)
                break
            except Exception as e:
                print(e)
                retries += 1
                time.sleep(5)
                if retries == 3:
                    print(f"Failed to get embedding for {text}")
                    # kill the function
                    raise   

    return embeddings

# %%
df = pd.DataFrame(
    joined_df.apply(
        lambda x: make_x(
            x["ddl"]
            + "\n\n"
            + x["question"]            
            + ("\n" + x["evidence"] if x["evidence"] else ""),
            x["db_id"],
            x["SQL"],
            x['question']
        ),
        axis=1,
    ).tolist()
)
df.columns = ["user_prompt", "db_id", "ideal_assistant_response", 'question']

df = df.sample(n=500, random_state=1234).reset_index(drop=True) 
# df = df.tail(10).reset_index(drop=True)

df['embeddings'] = get_embeddings(df, 'question')
start = time.time()
df['similar_questions'] = find_similar_questions(df, df_reference_questions, num_questions=0)
end = time.time()
print(f"Time to find similar questions: {end - start} seconds")

df.head()
# Out:
# Time to find similar questions: 81.02810716629028 seconds
#                                          user_prompt                  db_id  \
# 0  Examination (\n\tID INT -- identification of t...  thrombosis_prediction
# 1  frpm (\n\tCDSCode TEXT -- CDSCode -- 011001701...     california_schools
# 2  "atom" (\n\t"atom_id" TEXT -- the unique id of...             toxicology
# 3  Examination (\n\tID INT -- identification of t...  thrombosis_prediction
# 4  badges (\n\tId INT -- 1, 2, 3, 4, 5\n\tUserId ...     codebase_community
#
#                             ideal_assistant_response  \
# 0  SELECT DISTINCT T1.ID, T1.SEX, T1.Birthday FRO...
# 1  SELECT GSserved FROM schools WHERE City = 'Ade...
# 2  SELECT COUNT(T.molecule_id) FROM molecule AS T...
# 3  SELECT COUNT(DISTINCT T1.ID) FROM Patient AS T...
# 4  SELECT COUNT(id) FROM users WHERE Reputation >...
#
#                                             question  \
# 0  List ID, sex and date of birth of patient whos...
# 1  What is the most common type of grade span ser...
# 2  Calculate the total carcinogenic molecules for...
# 3  Excluding all P only ANA Pattern patients, how...
# 4  How many users whose reputations are higher th...
#
#                                           embeddings similar_questions
# 0  [0.015778781846165657, 0.005091146100312471, -...                []
# 1  [0.014656159095466137, 0.02713850326836109, -0...                []
# 2  [-0.026426946744322777, -0.053564295172691345,...                []
# 3  [-0.024667911231517792, 0.005138586275279522, ...                []
# 4  [-0.015890464186668396, -0.012033837847411633,...                []

# %%
SYSTEM_PROMPT = """You are a principal data engineer. Help users write SQL queries for a SQLite database to answer their questions.

For every user question, you'll be provided with context about their database in the following format:
<table> (
    <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
    ...
    <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
    FOREIGN KEY (<column>) REFERENCES <table> (<column>)
)

Not all columns have descriptions or example values. Not all tables have foreign keys.

You should only respond in this JSON format:
{
    "sql": "the sql that answers the user's question"
}"""

# %%
MAX_RETRIES = 3
RETRY_DELAY = 10  # seconds


def create_response(model, msgs, response_max_tokens=1000):
    for attempt in range(MAX_RETRIES):
        if dryrun:
            return {"choices": [{"message": {"content": "SELECT 1"}}]}
        try:
            return openai.chat.completions.create(
                model=model,
                messages=msgs,
                temperature=0.0,
                n=1,
                max_tokens=response_max_tokens,
                seed=9385
            )
        except (OpenAITimeout, RequestsTimeout, APIError):
            if attempt < MAX_RETRIES - 1:  # i.e. if not the last attempt
                print(f"Timeout occurred, retrying in {RETRY_DELAY} seconds...")
                time.sleep(RETRY_DELAY)
            else:
                raise


def generate_similar_examples(_row, _df_reference_questions):
    similar_questions_indices = _row['similar_questions']
    msgs = []
    for idx in similar_questions_indices:
        ref_row = _df_reference_questions.iloc[idx]
        user_msg = {"role": "user", "content": ref_row['user_prompt']}
        assistant_msg = {
            "role": "assistant",
            "content": json.dumps({
                "sql": ref_row['SQL']
            }, indent=4)
        }
        msgs.append(user_msg)
        msgs.append(assistant_msg)

    return msgs

            
empty_sql_correction_msg = [{"role": "user", "content": "You must reply with SQL."}]

def grab_response_from_chatgpt(model, user_msg, similar_questions):
    user_msg = user_msg
    intro_messages = [{"role": "system", "content": SYSTEM_PROMPT}] + similar_questions
    msgs = intro_messages + [{"role": "user", "content": user_msg}]
    for msg in msgs:
        print(msg['content'])
    response = create_response(model, msgs).choices[0].message.content
    print(response)
    try:
        sql = json.loads(response)["sql"]
    except Exception as e:
        print(e)
        if "Invalid \escape" in str(e):
            print("Invalid escape character detected in response. Attempting to correct...")
            response = response.replace("\\", "\\\\")
            sql = json.loads(response)["sql"]

    if sql == "":
        msgs += [{"role": "assistant", "content": response}]
        msgs += empty_sql_correction_msg
        response = create_response(model, msgs).choices[0].message.content
    return response


def error_correction_from_chatgpt(model, user_msg, predicted_sql, error_message):
    msgs = [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": user_msg},
        {"role": "assistant", "content": predicted_sql},
        {
            "role": "user",
            "content": f"That SQL produced this error message: \"{error_message}\". Write a new query. If you receieved a 'no such column' error, consider whether you pulled the column from the correct table. Don't apologize. Respond only with SQL.",
        },
    ]
    return create_response(model, msgs).choices[0].message.content


def execute_query_safe(db_name, query):
    """Executes a SQL query safely and returns the fetched results."""
    path = f"{DB_DIR}/{db_name}/{db_name}.sqlite"
    conn = sqlite3.connect(path, timeout=30)
    cursor = conn.cursor()
    try:
        cursor.execute(query)
        return set(cursor.fetchall()), None
    except sqlite3.OperationalError as e:
        return None, str(e)
    except Exception as e:
        return None, f"Unexpected error: {e}"
    finally:
        conn.close()


def correct_sql_and_execute(db_name, model, user_msg, predicted_query, error_msg, timeout=30):
    """Attempts to correct a SQL query and executes the corrected version."""
    corrected_sql_response = error_correction_from_chatgpt(
        model, user_msg, predicted_query, error_msg
    )
    try:
        corrected_sql = json.loads(corrected_sql_response)["sql"]
        print(f"Corrected SQL: {corrected_sql}")
        result_set, error = func_timeout(timeout, execute_query_safe, args=(db_name, corrected_sql))
        if error:
            print(error)
            return None, corrected_sql
        return result_set, corrected_sql
    except FunctionTimedOut:
        print("SQL correction timed out")
        return None, corrected_sql
    except Exception as e:
        print(str(e))
        return (None, "Failed to correct SQL"), None
    

def check_execution_accuracy(predicted_query, ideal_query, db_name, model, user_msg):
    is_equal = False
    _predicted_set = set()
    predicted_query_final = predicted_query
    error = None

    # Execute the ideal query
    try:
        ideal_set, error = func_timeout(30, execute_query_safe, args=(db_name, ideal_query))
    except FunctionTimedOut:
        error = "Ideal SQL execution timed out"
        ideal_set = set()
    except Exception as e:
        error = f"Unexpected error during ideal SQL execution: {str(e)}"
        ideal_set = set()
    if error:
        print(f"Error with ideal SQL: {error}")
        return is_equal, _predicted_set, predicted_query
    
    error = None
    
    # Execute the predicted query
    try:
        _predicted_set, error = func_timeout(30, execute_query_safe, args=(db_name, predicted_query))
    except FunctionTimedOut:
        error = "Predicted SQL execution timed out"
        _predicted_set = set()
    except Exception as e:
        error = f"Unexpected error during predicted SQL execution: {str(e)}"
        _predicted_set = set()
    if error:
        print(f"Error with predicted SQL: {error}")
        result_set, corrected_sql = correct_sql_and_execute(
            db_name, model, user_msg, predicted_query, error
        )
        _predicted_set = result_set  # Update _predicted_set with result from corrected execution
        if corrected_sql:
            predicted_query_final = corrected_sql

    # Check if correction is needed due to empty result set
    if _predicted_set is not None and len(_predicted_set) == 0:
        print("Empty result set")
        result_set, corrected_sql = correct_sql_and_execute(
            db_name, model, user_msg, predicted_query, "Empty result set"
        )
        _predicted_set = result_set  # Update _predicted_set with result from corrected execution
        if corrected_sql:
            predicted_query_final = corrected_sql

    # Final comparison
    if _predicted_set is not None and ideal_set is not None and _predicted_set == ideal_set:
        is_equal = True
    elif _predicted_set is None and ideal_set is None:
        is_equal = True

    return is_equal, _predicted_set, predicted_query_final

# %%
predicted_res = []
first_predicted_queries = []
final_predicted_queries = []
execution_accuracies = []
query_changes = []

df_pred = df.copy()

for index, row in df_pred.iterrows():
    completion = ""
    print(f"processing row {index} of {len(df_pred)}")
    similar_questions = generate_similar_examples(row, df_reference_questions)
    try:
        completion = grab_response_from_chatgpt(
            model=DEFAULT_MODEL, user_msg=row["user_prompt"], similar_questions=similar_questions
        )
    except Exception as e:
        if "Read timed out" in str(e) or "You requested a model that is not compatible with this engine" in str(e):
            print("The request to OpenAI API timed out or the model was incompatible. Retrying...")
            completion = grab_response_from_chatgpt(
                model=DEFAULT_MODEL, user_msg=row["user_prompt"], similar_questions=similar_questions
            )
        else:
            print(f"An unexpected error occurred: {e}")
    print('here 1')
    # first_predicted_query = ast.literal_eval(completion)["sql"]  # type: ignore
    try:
        first_predicted_query = json.loads(completion)["sql"]
    except Exception as e:
        print(e)
        first_predicted_query = ""
    db_name = row["db_id"]
    print('here 2')
    execution_accuracy, predicted_set, final_predicted_query = check_execution_accuracy(
        first_predicted_query,
        row["ideal_assistant_response"],
        db_name,
        DEFAULT_MODEL,
        row["user_prompt"],
    )
    print('here 3')

    execution_accuracies.append(1 if execution_accuracy else 0)
    first_predicted_queries.append(first_predicted_query)
    final_predicted_queries.append(final_predicted_query)
    predicted_res.append(predicted_set)
    print('here 5')


df_pred["first_predicted_query"] = first_predicted_queries
df_pred["final_predicted_query"] = final_predicted_queries
df_pred["predicted_res"] = predicted_res
df_pred["execution_accuracy"] = execution_accuracies

df_pred["formatted_string"] = (
    df_pred["final_predicted_query"] + "\t----- bird -----\t" + df_pred["db_id"]
)

df_pred.head()
# Out:
# processing row 0 of 500
# You are a principal data engineer. Help users write SQL queries for a SQLite database to answer their questions.
#
# For every user question, you'll be provided with context about their database in the following format:
# <table> (
#     <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
#     ...
#     <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
#     FOREIGN KEY (<column>) REFERENCES <table> (<column>)
# )
#
# Not all columns have descriptions or example values. Not all tables have foreign keys.
#
# You should only respond in this JSON format:
# {
#     "sql": "the sql that answers the user's question"
# }
# Examination (
# 	ID INT -- identification of the patient -- 14872, 48473, 102490, 108788, 122405
# 	"Examination Date" DATE -- 1997-05-27, 1992-12-21, 1995-04-20, 1997-05-06, 1998-04-02
# 	"aCL IgG" FLOAT -- 1.3, 4.3, 2.3, 0.0
# 	"aCL IgM" FLOAT -- 1.6, 4.6, 2.5, 0.0, 4.0
# 	ANA INT -- anti-nucleus antibody concentration -- 256, 0, 16, 4
# 	"ANA Pattern" TEXT -- anti-nucleus antibody concentration -- P, "P,S", S
# 	"aCL IgA" INT -- 0, 3, 4
# 	Diagnosis TEXT -- disease names -- "MCTD, AMI", SLE, PSS, "SLE, SjS, vertigo"
# 	KCT TEXT -- measure of degree of coagulation -- -
# 	RVVT TEXT -- measure of degree of coagulation -- -
# 	LAC TEXT -- measure of degree of coagulation -- -
# 	Symptoms TEXT -- other symptoms observed -- AMI
# 	Thrombosis INT -- degree of thrombosis -- 1, 0
# 	FOREIGN KEY (ID) REFERENCES Patient (ID)
# )
# Patient (
# 	ID INT -- identification of the patient -- 2110, 11408, 12052, 14872, 27654
# 	SEX TEXT -- Sex -- F
# 	Birthday DATE -- Birthday -- 1934-02-13, 1937-05-02, 1956-04-14, 1953-09-21, 1936-03-25
# 	Description DATE -- the first date when a patient data was recorded -- 1994-02-14, 1996-12-01, 1991-08-13, 1997-08-13
# 	"First Date" DATE -- 1993-02-10, 1973-01-01, 1992-02-03
# 	Admission TEXT -- patient was admitted to the hospital (+) or followed at the outpatient clinic (-) -- +
# 	Diagnosis TEXT -- disease names -- RA susp., PSS, SLE, MCTD, "RA, SLE susp"
# )
# Laboratory (
# 	ID INT -- identification of the patient -- 27654
# 	Date DATE -- Date of the laboratory tests (YYMMDD) -- 1991-09-11, 1991-09-17, 1991-09-19, 1991-09-20, 1991-09-21
# 	GOT INT -- AST glutamic oxaloacetic transaminase -- 34, 29, 26, 23
# 	GPT INT -- ALT glutamic pyruvic transaminase -- 36, 31, 22, 18
# 	LDH INT -- lactate dehydrogenase -- 567, 579, 684, 552
# 	ALP INT -- alkaliphophatase -- 166, 154, 138, 131
# 	TP FLOAT -- total protein -- 4.5, 5.1, 5.5, 4.2
# 	ALB FLOAT -- albumin -- 3.3, 3.4, 3.6, 2.9
# 	UA FLOAT -- uric acid -- 3.8, 4.2, 4.9, 4.8
# 	UN INT -- urea nitrogen -- 29, 36, 34, 22
# 	CRE FLOAT -- creatinine -- 0.8, 0.9, 0.7
# 	"T-BIL" FLOAT
# 	"T-CHO" INT
# 	TG INT -- triglyceride
# 	CPK INT -- creatinine phosphokinase -- 9, 10
# 	GLU INT -- blood glucose -- 88
# 	WBC FLOAT -- White blood cell -- 5.0, 10.4, 10.5, 10.3, 14.3
# 	RBC FLOAT -- Red blood cell -- 2.6, 2.9, 3.4, 3.2
# 	HGB FLOAT -- Hemoglobin -- 6.4, 6.7, 7.9, 6.1, 7.2
# 	HCT FLOAT -- Hematoclit -- 20.3, 21.6, 24.7, 19.3, 23.4
# 	PLT INT -- platelet -- 227, 242, 233, 201, 215
# 	PT FLOAT -- prothrombin time
# 	APTT INT -- activated partial prothrombin time
# 	FG FLOAT -- fibrinogen
# 	PIC INT
# 	TAT INT
# 	TAT2 INT
# 	"U-PRO" TEXT
# 	IGG INT -- Ig G -- 339, 771, 430
# 	IGA INT -- Ig A -- 145, 188, 118
# 	IGM INT -- Ig M -- 46, 132, 56
# 	CRP TEXT -- C-reactive protein -- 0.6, 2.7, 1.2
# 	RA TEXT -- Rhuematoid Factor
# 	RF TEXT -- RAHA
# 	C3 INT -- complement 3
# 	C4 INT -- complement 4
# 	RNP TEXT -- anti-ribonuclear protein
# 	SM TEXT -- anti-SM
# 	SC170 TEXT -- anti-scl70
# 	SSA TEXT -- anti-SSA
# 	SSB TEXT -- anti-SSB
# 	CENTROMEA TEXT -- anti-centromere
# 	DNA TEXT -- anti-DNA
# 	"DNA-II" INT
# 	FOREIGN KEY (ID) REFERENCES Patient (ID)
# )
#
# List ID, sex and date of birth of patient whose total protein (TP) below the lower range of the normal index.
# total protein (TP) below the lower range of the normal index refers to TP < 6.0
# {
#     "sql": "SELECT Patient.ID, Patient.SEX, Patient.Birthday FROM Patient JOIN Laboratory ON Patient.ID = Laboratory.ID WHERE Laboratory.TP < 6.0"
# }
# here 1
# here 2
# here 3
# here 5
# processing row 1 of 500
# You are a principal data engineer. Help users write SQL queries for a SQLite database to answer their questions.
#
# For every user question, you'll be provided with context about their database in the following format:
# <table> (
#     <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
#     ...
#     <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
#     FOREIGN KEY (<column>) REFERENCES <table> (<column>)
# )
#
# Not all columns have descriptions or example values. Not all tables have foreign keys.
#
# You should only respond in this JSON format:
# {
#     "sql": "the sql that answers the user's question"
# }
# frpm (
# 	CDSCode TEXT -- CDSCode -- 01100170109835, 01100170112607, 01100170118489, 01100170123968
# 	"Academic Year" TEXT -- 2014-2015
# 	"County Code" TEXT -- 01
# 	"District Code" INT -- 10017
# 	"School Code" TEXT -- 0109835, 0112607, 0118489, 0123968, 0124172
# 	"County Name" TEXT -- Alameda
# 	"District Name" TEXT -- Alameda County Office of Education
# 	"School Name" TEXT -- FAME Public Charter, Envision Academy for Arts & Technology
# 	"District Type" TEXT -- County Office of Education (COE)
# 	"School Type" TEXT -- K-12 Schools (Public), High Schools (Public), Elementary Schools (Public)
# 	"Educational Option Type" TEXT -- Traditional
# 	"NSLP Provision Status" TEXT -- Breakfast Provision 2
# 	"Charter School (Y/N)" INT -- 1
# 	"Charter School Number" TEXT -- 0728, 0811, 1049, 1284, 1296
# 	"Charter Funding Type" TEXT -- Directly funded
# 	IRC INT -- 1
# 	"Low Grade" TEXT -- K, 9
# 	"High Grade" TEXT -- 12, 8
# 	"Enrollment (K-12)" FLOAT -- 1087.0, 395.0, 244.0, 191.0, 257.0
# 	"Free Meal Count (K-12)" FLOAT -- 565.0, 186.0, 134.0, 113.0, 14.0
# 	"Percent (%) Eligible Free (K-12)" FLOAT -- 0.519779208831647, 0.470886075949367, 0.549180327868853
# 	"FRPM Count (K-12)" FLOAT -- 715.0, 186.0, 175.0, 139.0, 21.0
# 	"Percent (%) Eligible FRPM (K-12)" FLOAT -- 0.657773689052438, 0.470886075949367, 0.717213114754098
# 	"Enrollment (Ages 5-17)" FLOAT -- 1070.0, 376.0, 230.0, 190.0, 257.0
# 	"Free Meal Count (Ages 5-17)" FLOAT -- 553.0, 182.0, 128.0, 113.0, 14.0
# 	"Percent (%) Eligible Free (Ages 5-17)" FLOAT -- 0.516822429906542, 0.484042553191489, 0.556521739130435
# 	"FRPM Count (Ages 5-17)" FLOAT -- 702.0, 182.0, 168.0, 139.0, 21.0
# 	"Percent (%) Eligible FRPM (Ages 5-17)" FLOAT -- 0.65607476635514, 0.484042553191489, 0.730434782608696
# 	"2013-14 CALPADS Fall 1 Certification Status" INT
# 	FOREIGN KEY (CDSCode) REFERENCES schools (CDSCode)
# )
# satscores (
# 	cds TEXT -- 1100170000000, 1100170109835, 1100170112607, 1100170118489
# 	rtype TEXT -- D, S
# 	sname TEXT -- FAME Public Charter, Envision Academy for Arts & Technology
# 	dname TEXT -- Alameda County Office of Education, Alameda Unified
# 	cname TEXT -- Alameda
# 	enroll12 INT -- 398, 62, 75, 61, 922
# 	NumTstTakr INT -- 88, 17, 71, 0, 544
# 	AvgScrRead INT -- 418, 503, 397, 521
# 	AvgScrMath INT -- 418, 546, 387
# 	AvgScrWrite INT -- 417, 505, 395, 519
# 	NumGE1500 INT -- 14, 9, 5, 333
# 	FOREIGN KEY (cds) REFERENCES schools (CDSCode)
# )
# schools (
# 	CDSCode TEXT -- 01100170000000, 01100170109835, 01100170112607, 01100170118489
# 	NCESDist TEXT -- 0691051
# 	NCESSchool TEXT -- 10546, 10947, 12283, 12844
# 	StatusType TEXT -- Active, Closed
# 	County TEXT -- Alameda
# 	District TEXT -- Alameda County Office of Education
# 	School TEXT -- FAME Public Charter, Envision Academy for Arts & Technology
# 	Street TEXT -- 313 West Winton Avenue, "39899 Balentine Drive, Suite 335"
# 	StreetAbr TEXT -- 313 West Winton Ave., "39899 Balentine Dr., Ste. 335"
# 	City TEXT -- Hayward, Newark, Oakland, Berkeley
# 	Zip TEXT -- 94544-1136, 94560-5359, 94612-3355, 94703-1414, 94606-4903
# 	State TEXT -- CA
# 	MailStreet TEXT -- 313 West Winton Avenue, "39899 Balentine Drive, Suite 335"
# 	MailStrAbr TEXT -- 313 West Winton Ave., "39899 Balentine Dr., Ste. 335"
# 	MailCity TEXT -- Hayward, Newark, Oakland
# 	MailZip TEXT -- 94544-1136, 94560-5359, 94612, 94606, 94606-4903
# 	MailState TEXT -- CA
# 	Phone TEXT -- (510) 887-0152, (510) 596-8901, (510) 686-4131
# 	Ext TEXT
# 	Website TEXT -- www.acoe.org, www.envisionacademy.org/, www.aspirepublicschools.org
# 	OpenDate DATE -- 2005-08-29, 2006-08-28, 2008-08-21, 2011-08-22
# 	ClosedDate DATE -- 2015-07-31, 2015-06-30
# 	Charter INT -- 1
# 	CharterNum TEXT -- 0728, 0811, 1049, 1284
# 	FundingType TEXT -- Directly funded
# 	DOC TEXT -- 00
# 	DOCType TEXT -- County Office of Education (COE)
# 	SOC TEXT -- 65, 66, 60
# 	SOCType TEXT -- K-12 Schools (Public), High Schools (Public), Elementary Schools (Public)
# 	EdOpsCode TEXT -- TRAD
# 	EdOpsName TEXT -- Traditional
# 	EILCode TEXT -- ELEMHIGH, HS, ELEM
# 	EILName TEXT -- Elementary-High Combination, High School, Elementary
# 	GSoffered TEXT -- K-12, 9-12, K-8
# 	GSserved TEXT -- K-12, 9-12, K-7
# 	Virtual TEXT -- P, N
# 	Magnet INT -- 0
# 	Latitude FLOAT -- 37.658212, 37.521436, 37.80452, 37.868991, 37.784648
# 	Longitude FLOAT -- -122.09713, -121.99391, -122.26815, -122.27844, -122.23863
# 	AdmFName1 TEXT -- L Karen, Laura, Clifford
# 	AdmLName1 TEXT -- Monroe, Robell, Thompson
# 	AdmEmail1 TEXT -- lkmonroe@acoe.org, laura@envisionacademy.org, cliffordt@communityschoolforcreativeeducation.org
# 	AdmFName2 TEXT
# 	AdmLName2 TEXT
# 	AdmEmail2 TEXT
# 	AdmFName3 TEXT
# 	AdmLName3 TEXT
# 	AdmEmail3 TEXT
# 	LastUpdate DATE -- 2015-06-23, 2015-09-01, 2015-06-18, 2015-07-01, 2016-07-18
# )
#
# What is the most common type of grade span served in the city of Adelanto?
# {
#     "sql": "SELECT GSserved, COUNT(*) AS count FROM schools WHERE City = 'Adelanto' GROUP BY GSserved ORDER BY count DESC LIMIT 1"
# }
# here 1
# here 2
# here 3
# here 5
# processing row 2 of 500
# You are a principal data engineer. Help users write SQL queries for a SQLite database to answer their questions.
#
# For every user question, you'll be provided with context about their database in the following format:
# <table> (
#     <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
#     ...
#     <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
#     FOREIGN KEY (<column>) REFERENCES <table> (<column>)
# )
#
# Not all columns have descriptions or example values. Not all tables have foreign keys.
#
# You should only respond in this JSON format:
# {
#     "sql": "the sql that answers the user's question"
# }
# "atom" (
# 	"atom_id" TEXT -- the unique id of atoms -- TR000_1, TR000_2, TR000_3, TR000_4, TR000_5
# 	"molecule_id" TEXT -- identifying the molecule to which the atom belongs -- TR000
# 	"element" TEXT -- the element of the toxicology  -- cl, c, h
# 	FOREIGN KEY ("molecule_id") REFERENCES "molecule" ("molecule_id")
# )
# "bond" (
# 	"bond_id" TEXT -- unique id representing bonds -- TR000_1_2, TR000_2_3, TR000_2_4, TR000_2_5, TR001_10_11
# 	"molecule_id" TEXT -- identifying the molecule in which the bond appears -- TR000, TR001
# 	"bond_type" TEXT -- type of the bond -- -, =
# 	FOREIGN KEY ("molecule_id") REFERENCES "molecule" ("molecule_id")
# )
# "connected" (
# 	"atom_id" TEXT -- id of the first atom -- TR000_1, TR000_2, TR000_3
# 	"atom_id2" TEXT -- id of the second atom -- TR000_2, TR000_1, TR000_3, TR000_4
# 	"bond_id" TEXT -- bond id representing bond between two atoms -- TR000_1_2, TR000_2_3, TR000_2_4
# 	FOREIGN KEY ("atom_id") REFERENCES "atom" ("atom_id")
# 	FOREIGN KEY ("atom_id2") REFERENCES "atom" ("atom_id")
# 	FOREIGN KEY ("bond_id") REFERENCES "bond" ("bond_id")
# )
# "molecule" (
# 	"molecule_id" TEXT -- unique id of molecule -- TR000, TR001, TR002, TR004, TR006
# 	"label" TEXT -- whether this molecule is carcinogenic or not -- +, -
# )
#
# Calculate the total carcinogenic molecules for molecule id from TR000 to TR030.
# label = '+' mean molecules are carcinogenic
# {
#     "sql": "SELECT COUNT(*) AS total_carcinogenic_molecules FROM molecule WHERE label = '+' AND molecule_id BETWEEN 'TR000' AND 'TR030'"
# }
# here 1
# here 2
# here 3
# here 5
# processing row 3 of 500
# You are a principal data engineer. Help users write SQL queries for a SQLite database to answer their questions.
#
# For every user question, you'll be provided with context about their database in the following format:
# <table> (
#     <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
#     ...
#     <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
#     FOREIGN KEY (<column>) REFERENCES <table> (<column>)
# )
#
# Not all columns have descriptions or example values. Not all tables have foreign keys.
#
# You should only respond in this JSON format:
# {
#     "sql": "the sql that answers the user's question"
# }
# Examination (
# 	ID INT -- identification of the patient -- 14872, 48473, 102490, 108788, 122405
# 	"Examination Date" DATE -- 1997-05-27, 1992-12-21, 1995-04-20, 1997-05-06, 1998-04-02
# 	"aCL IgG" FLOAT -- 1.3, 4.3, 2.3, 0.0
# 	"aCL IgM" FLOAT -- 1.6, 4.6, 2.5, 0.0, 4.0
# 	ANA INT -- anti-nucleus antibody concentration -- 256, 0, 16, 4
# 	"ANA Pattern" TEXT -- anti-nucleus antibody concentration -- P, "P,S", S
# 	"aCL IgA" INT -- 0, 3, 4
# 	Diagnosis TEXT -- disease names -- "MCTD, AMI", SLE, PSS, "SLE, SjS, vertigo"
# 	KCT TEXT -- measure of degree of coagulation -- -
# 	RVVT TEXT -- measure of degree of coagulation -- -
# 	LAC TEXT -- measure of degree of coagulation -- -
# 	Symptoms TEXT -- other symptoms observed -- AMI
# 	Thrombosis INT -- degree of thrombosis -- 1, 0
# 	FOREIGN KEY (ID) REFERENCES Patient (ID)
# )
# Patient (
# 	ID INT -- identification of the patient -- 2110, 11408, 12052, 14872, 27654
# 	SEX TEXT -- Sex -- F
# 	Birthday DATE -- Birthday -- 1934-02-13, 1937-05-02, 1956-04-14, 1953-09-21, 1936-03-25
# 	Description DATE -- the first date when a patient data was recorded -- 1994-02-14, 1996-12-01, 1991-08-13, 1997-08-13
# 	"First Date" DATE -- 1993-02-10, 1973-01-01, 1992-02-03
# 	Admission TEXT -- patient was admitted to the hospital (+) or followed at the outpatient clinic (-) -- +
# 	Diagnosis TEXT -- disease names -- RA susp., PSS, SLE, MCTD, "RA, SLE susp"
# )
# Laboratory (
# 	ID INT -- identification of the patient -- 27654
# 	Date DATE -- Date of the laboratory tests (YYMMDD) -- 1991-09-11, 1991-09-17, 1991-09-19, 1991-09-20, 1991-09-21
# 	GOT INT -- AST glutamic oxaloacetic transaminase -- 34, 29, 26, 23
# 	GPT INT -- ALT glutamic pyruvic transaminase -- 36, 31, 22, 18
# 	LDH INT -- lactate dehydrogenase -- 567, 579, 684, 552
# 	ALP INT -- alkaliphophatase -- 166, 154, 138, 131
# 	TP FLOAT -- total protein -- 4.5, 5.1, 5.5, 4.2
# 	ALB FLOAT -- albumin -- 3.3, 3.4, 3.6, 2.9
# 	UA FLOAT -- uric acid -- 3.8, 4.2, 4.9, 4.8
# 	UN INT -- urea nitrogen -- 29, 36, 34, 22
# 	CRE FLOAT -- creatinine -- 0.8, 0.9, 0.7
# 	"T-BIL" FLOAT
# 	"T-CHO" INT
# 	TG INT -- triglyceride
# 	CPK INT -- creatinine phosphokinase -- 9, 10
# 	GLU INT -- blood glucose -- 88
# 	WBC FLOAT -- White blood cell -- 5.0, 10.4, 10.5, 10.3, 14.3
# 	RBC FLOAT -- Red blood cell -- 2.6, 2.9, 3.4, 3.2
# 	HGB FLOAT -- Hemoglobin -- 6.4, 6.7, 7.9, 6.1, 7.2
# 	HCT FLOAT -- Hematoclit -- 20.3, 21.6, 24.7, 19.3, 23.4
# 	PLT INT -- platelet -- 227, 242, 233, 201, 215
# 	PT FLOAT -- prothrombin time
# 	APTT INT -- activated partial prothrombin time
# 	FG FLOAT -- fibrinogen
# 	PIC INT
# 	TAT INT
# 	TAT2 INT
# 	"U-PRO" TEXT
# 	IGG INT -- Ig G -- 339, 771, 430
# 	IGA INT -- Ig A -- 145, 188, 118
# 	IGM INT -- Ig M -- 46, 132, 56
# 	CRP TEXT -- C-reactive protein -- 0.6, 2.7, 1.2
# 	RA TEXT -- Rhuematoid Factor
# 	RF TEXT -- RAHA
# 	C3 INT -- complement 3
# 	C4 INT -- complement 4
# 	RNP TEXT -- anti-ribonuclear protein
# 	SM TEXT -- anti-SM
# 	SC170 TEXT -- anti-scl70
# 	SSA TEXT -- anti-SSA
# 	SSB TEXT -- anti-SSB
# 	CENTROMEA TEXT -- anti-centromere
# 	DNA TEXT -- anti-DNA
# 	"DNA-II" INT
# 	FOREIGN KEY (ID) REFERENCES Patient (ID)
# )
#
# Excluding all P only ANA Pattern patients, how many of the remainder are women born between 1980 and 1989?
# Excluding all P only ANA Pattern refers to `ANA Pattern`! = 'p'; women refers to SEX = 'F'; born between 1980 and 1989 refers to BIRTHDAY
# {
#     "sql": "SELECT COUNT(DISTINCT Patient.ID) FROM Patient JOIN Examination ON Patient.ID = Examination.ID WHERE Examination.\"ANA Pattern\" != 'P' AND Patient.SEX = 'F' AND Patient.Birthday BETWEEN '1980-01-01' AND '1989-12-31'"
# }
# here 1
# here 2
# here 3
# here 5
# processing row 4 of 500
# You are a principal data engineer. Help users write SQL queries for a SQLite database to answer their questions.
#
# For every user question, you'll be provided with context about their database in the following format:
# <table> (
#     <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
#     ...
#     <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
#     FOREIGN KEY (<column>) REFERENCES <table> (<column>)
# )
#
# Not all columns have descriptions or example values. Not all tables have foreign keys.
#
# You should only respond in this JSON format:
# {
#     "sql": "the sql that answers the user's question"
# }
# badges (
# 	Id INT -- 1, 2, 3, 4, 5
# 	UserId INT -- 5, 6, 8, 23, 36
# 	Name TEXT -- Teacher
# 	Date DATETIME -- 2010-07-19 19:39:07.0
# 	FOREIGN KEY (UserId) REFERENCES users (Id)
# )
# comments (
# 	Id INT -- 1, 2, 3, 4, 5
# 	PostId INT -- 3, 5, 9
# 	Score INT -- 5, 0, 11, 1
# 	Text TEXT -- "Could be a poster child fo argumentative and subjective.  At the least, need to define \"valuable\"."
# 	CreationDate DATETIME -- 2010-07-19 19:15:52.0, 2010-07-19 19:16:14.0, 2010-07-19 19:18:54.0
# 	UserId INT -- 13, 37, 5
# 	UserDisplayName TEXT
# 	FOREIGN KEY (PostId) REFERENCES posts (Id)
# 	FOREIGN KEY (UserId) REFERENCES users (Id)
# )
# postHistory (
# 	Id INT -- the post history id -- 1, 2, 3, 4, 5
# 	PostHistoryTypeId INT -- the id of the post history type -- 2, 1, 3
# 	PostId INT -- the unique id of the post -- 1, 2
# 	RevisionGUID TEXT -- the revision globally unique id of the post -- e58bf7fd-e60f-4c58-a6e4-dfc91cf98a69, 18bf9150-f1cb-432d-b7b7-26d2f8e33581
# 	CreationDate DATETIME -- the creation date of the post -- 2010-07-19 19:12:12.0, 2010-07-19 19:12:57.0
# 	UserId INT -- the user who post the post -- 8, 24
# 	Text TEXT -- the detailed content of the post -- How should I elicit prior distributions from experts when fitting a Bayesian model?
# 	Comment TEXT -- comments of the post
# 	UserDisplayName TEXT -- user's display name
# 	FOREIGN KEY (PostId) REFERENCES posts (Id)
# 	FOREIGN KEY (UserId) REFERENCES users (Id)
# )
# postLinks (
# 	Id INT -- 108, 145, 217, 263, 264
# 	CreationDate DATETIME -- 2010-07-21 14:47:33.0, 2010-07-23 16:30:41.0, 2010-07-26 20:12:15.0
# 	PostId INT -- 395, 548, 375, 769
# 	RelatedPostId INT -- 173, 539, 30, 31, 6
# 	LinkTypeId INT -- 1
# 	FOREIGN KEY (PostId) REFERENCES posts (Id)
# 	FOREIGN KEY (RelatedPostId) REFERENCES posts (Id)
# )
# posts (
# 	Id INT -- 1, 2, 3, 4, 5
# 	PostTypeId INT -- 1, 2
# 	AcceptedAnswerId INT -- 15, 59, 5, 135
# 	CreaionDate DATETIME -- 2010-07-19 19:12:12.0, 2010-07-19 19:12:57.0, 2010-07-19 19:13:28.0
# 	Score INT -- 23, 22, 54, 13, 81
# 	ViewCount INT -- 1278, 8198, 3613, 5224
# 	Body TEXT -- <p>How should I elicit prior distributions from experts when fitting a Bayesian model?</p>
# 	OwnerUserId INT -- 8, 24, 18, 23
# 	LasActivityDate DATETIME -- 2010-09-15 21:08:26.0, 2012-11-12 09:21:54.0, 2013-05-27 14:48:36.0
# 	Title TEXT -- Eliciting priors from experts, What is normality?
# 	Tags TEXT -- <bayesian><prior><elicitation>, <distributions><normality>
# 	AnswerCount INT -- 5, 7, 19
# 	CommentCount INT -- 1, 4, 2, 3
# 	FavoriteCount INT -- 14, 8, 36, 2
# 	LastEditorUserId INT -- 88, 183, 23
# 	LastEditDate DATETIME -- 2010-08-07 17:56:44.0, 2011-02-12 05:50:03.0, 2010-07-19 19:21:15.0
# 	CommunityOwnedDate DATETIME -- 2010-07-19 19:13:28.0, 2010-07-19 19:14:43.0
# 	ParentId INT -- 3
# 	ClosedDate DATETIME
# 	OwnerDisplayName TEXT
# 	LastEditorDisplayName TEXT
# 	FOREIGN KEY (LastEditorUserId) REFERENCES users (Id)
# 	FOREIGN KEY (OwnerUserId) REFERENCES users (Id)
# 	FOREIGN KEY (ParentId) REFERENCES posts (Id)
# )
# tags (
# 	Id INT -- 1, 2, 3, 4, 5
# 	TagName TEXT -- bayesian, prior, elicitation, normality, open-source
# 	Count INT -- 1342, 168, 6, 191, 13
# 	ExcerptPostId INT -- 20258, 62158, 67815
# 	WikiPostId INT -- 20257, 62157, 67814
# 	FOREIGN KEY (ExcerptPostId) REFERENCES posts (Id)
# )
# users (
# 	Id INT -- -1, 2, 3, 4, 5
# 	Reputation INT -- 1, 101, 6792
# 	CreationDate DATETIME -- 2010-07-19 06:55:26.0, 2010-07-19 14:01:36.0, 2010-07-19 15:34:50.0
# 	DisplayName TEXT -- Community, Geoff Dalgas, Jarrod Dixon, Emmett, Shane
# 	LastAccessDate DATETIME -- 2010-07-19 06:55:26.0, 2013-11-12 22:07:23.0, 2014-08-08 06:42:58.0
# 	WebsiteUrl TEXT -- http://meta.stackexchange.com/, http://stackoverflow.com
# 	Location TEXT -- on the server farm, "Corvallis, OR", "New York, NY"
# 	AboutMe TEXT -- "<p>Hi, I\"m not really a person.</p>  <p>I\"m a background process that helps keep this site clean!</p"
# 	Views INT -- 0, 25, 22, 11, 1145
# 	UpVotes INT -- 5007, 3, 19, 0, 662
# 	DownVotes INT -- 1920, 0, 5
# 	AccountId INT -- -1, 2, 3, 1998, 54503
# 	Age INT -- 37, 35, 28
# 	ProfileImageUrl TEXT -- http://i.stack.imgur.com/d1oHX.jpg
# )
# votes (
# 	Id INT -- 1, 2, 3, 4, 5
# 	PostId INT -- 3, 2, 5
# 	VoteTypeId INT -- 2
# 	CreationDate DATE -- 2010-07-19
# 	UserId INT
# 	BountyAmount INT
# 	FOREIGN KEY (PostId) REFERENCES posts (Id)
# 	FOREIGN KEY (UserId) REFERENCES users (Id)
# )
#
# How many users whose reputations are higher than 2000 and the number of views is higher than 1000?
# reputations are higher than 2000 refer to Reputation > 2000; number of views is higher than 1000 refers to Views > 1000;
# {
#     "sql": "SELECT COUNT(*) FROM users WHERE Reputation > 2000 AND Views > 1000"
# }
# here 1
# here 2
# here 3
# here 5
# processing row 5 of 500
# You are a principal data engineer. Help users write SQL queries for a SQLite database to answer their questions.
#
# For every user question, you'll be provided with context about their database in the following format:
# <table> (
#     <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
#     ...
#     <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
#     FOREIGN KEY (<column>) REFERENCES <table> (<column>)
# )
#
# Not all columns have descriptions or example values. Not all tables have foreign keys.
#
# You should only respond in this JSON format:
# {
#     "sql": "the sql that answers the user's question"
# }
# circuits (
# 	circuitId INT -- 2, 3, 4, 5, 6
# 	circuitRef TEXT -- sepang, bahrain, catalunya, istanbul, monaco
# 	name TEXT -- Sepang International Circuit, Bahrain International Circuit
# 	location TEXT -- Kuala Lumpur, Sakhir, Montmeló, Istanbul, Monte-Carlo
# 	country TEXT -- Malaysia, Bahrain, Spain, Turkey, Monaco
# 	lat FLOAT -- 2.76083, 26.0325, 41.57, 40.9517, 43.7347
# 	lng FLOAT -- 101.738, 50.5106, 2.26111, 29.405, 7.42056
# 	alt INT
# 	url TEXT -- http://en.wikipedia.org/wiki/Sepang_International_Circuit
# )
# constructors (
# 	constructorId INT -- 1, 2, 3, 4, 5
# 	constructorRef TEXT -- mclaren, bmw_sauber, williams, renault, toro_rosso
# 	name TEXT -- McLaren, BMW Sauber, Williams, Renault, Toro Rosso
# 	nationality TEXT -- British, German, French, Italian
# 	url TEXT -- http://en.wikipedia.org/wiki/McLaren, http://en.wikipedia.org/wiki/BMW_Sauber
# )
# drivers (
# 	driverId INT -- 1, 2, 3, 4, 5
# 	driverRef TEXT -- hamilton, heidfeld, rosberg, alonso, kovalainen
# 	number INT -- 44, 6, 14
# 	code TEXT -- HAM, HEI, ROS, ALO, KOV
# 	forename TEXT -- Lewis, Nick, Nico, Fernando, Heikki
# 	surname TEXT -- Hamilton, Heidfeld, Rosberg, Alonso, Kovalainen
# 	dob DATE -- 1985-01-07, 1977-05-10, 1985-06-27, 1981-07-29, 1981-10-19
# 	nationality TEXT -- British, German, Spanish, Finnish
# 	url TEXT -- http://en.wikipedia.org/wiki/Lewis_Hamilton, http://en.wikipedia.org/wiki/Nick_Heidfeld
# )
# seasons (
# 	year INT -- 1950, 1951, 1952, 1953, 1954
# 	url TEXT -- http://en.wikipedia.org/wiki/1950_Formula_One_season
# )
# races (
# 	raceId INT -- 1, 2, 3, 4, 5
# 	year INT -- 2009
# 	round INT -- 1, 2, 3, 4, 5
# 	circuitId INT -- 1, 2, 17, 3, 4
# 	name TEXT -- Australian Grand Prix, Malaysian Grand Prix, Chinese Grand Prix
# 	date DATE -- 2009-03-29, 2009-04-05, 2009-04-19, 2009-04-26, 2009-05-10
# 	time TEXT -- 06:00:00, 09:00:00, 07:00:00, 12:00:00
# 	url TEXT -- http://en.wikipedia.org/wiki/2009_Australian_Grand_Prix
# 	FOREIGN KEY (year) REFERENCES seasons (year)
# 	FOREIGN KEY (circuitId) REFERENCES circuits (circuitId)
# )
# constructorResults (
# 	constructorResultsId INT -- 1, 2, 3, 4, 5
# 	raceId INT -- 18
# 	constructorId INT -- 1, 2, 3, 4, 5
# 	points FLOAT -- 14.0, 8.0, 9.0, 5.0, 2.0
# 	status TEXT
# 	FOREIGN KEY (raceId) REFERENCES races (raceId)
# 	FOREIGN KEY (constructorId) REFERENCES constructors (constructorId)
# )
# constructorStandings (
# 	constructorStandingsId INT -- 1, 2, 3, 4, 5
# 	raceId INT -- 18
# 	constructorId INT -- 1, 2, 3, 4, 5
# 	points FLOAT -- 14.0, 8.0, 9.0, 5.0, 2.0
# 	position INT -- 1, 3, 2, 4, 5
# 	positionText TEXT -- 1, 3, 2, 4, 5
# 	wins INT -- 1, 0
# 	FOREIGN KEY (raceId) REFERENCES races (raceId)
# 	FOREIGN KEY (constructorId) REFERENCES constructors (constructorId)
# )
# driverStandings (
# 	driverStandingsId INT -- 1, 2, 3, 4, 5
# 	raceId INT -- 18
# 	driverId INT -- 1, 2, 3, 4, 5
# 	points FLOAT -- 10.0, 8.0, 6.0, 5.0, 4.0
# 	position INT -- 1, 2, 3, 4, 5
# 	positionText TEXT -- 1, 2, 3, 4, 5
# 	wins INT -- 1, 0
# 	FOREIGN KEY (raceId) REFERENCES races (raceId)
# 	FOREIGN KEY (driverId) REFERENCES drivers (driverId)
# )
# lapTimes (
# 	raceId INT -- 1
# 	driverId INT -- 1
# 	lap INT -- 1, 2, 3, 4, 5
# 	position INT -- 13, 12, 11, 10
# 	time TEXT -- 1:49.088, 1:33.740, 1:31.600, 1:31.067, 1:32.129
# 	milliseconds INT -- 109088, 93740, 91600, 91067, 92129
# 	FOREIGN KEY (raceId) REFERENCES races (raceId)
# 	FOREIGN KEY (driverId) REFERENCES drivers (driverId)
# )
# pitStops (
# 	raceId INT -- 841
# 	driverId INT -- 1, 2, 3
# 	stop INT -- 1, 2
# 	lap INT -- 16, 36, 15, 30
# 	time TEXT -- 17:28:24, 17:59:29, 17:27:41, 17:51:32, 17:29:00
# 	duration TEXT -- 23.227, 23.199, 22.994, 25.098, 23.716
# 	milliseconds INT -- 23227, 23199, 22994, 25098, 23716
# 	FOREIGN KEY (raceId) REFERENCES races (raceId)
# 	FOREIGN KEY (driverId) REFERENCES drivers (driverId)
# )
# qualifying (
# 	qualifyId INT -- 1, 2, 3, 4, 5
# 	raceId INT -- 18
# 	driverId INT -- 1, 9, 5, 13, 2
# 	constructorId INT -- 1, 2, 6
# 	number INT -- 22, 4, 23, 2, 3
# 	position INT -- 1, 2, 3, 4, 5
# 	q1 TEXT -- 1:26.572, 1:26.103, 1:25.664, 1:25.994, 1:25.960
# 	q2 TEXT -- 1:25.187, 1:25.315, 1:25.452, 1:25.691, 1:25.518
# 	q3 TEXT -- 1:26.714, 1:26.869, 1:27.079, 1:27.178, 1:27.236
# 	FOREIGN KEY (raceId) REFERENCES races (raceId)
# 	FOREIGN KEY (driverId) REFERENCES drivers (driverId)
# 	FOREIGN KEY (constructorId) REFERENCES constructors (constructorId)
# )
# status (
# 	statusId INT -- 1, 2, 3, 4, 5
# 	status TEXT -- Finished, Disqualified, Accident, Collision, Engine
# )
# results (
# 	resultId INT -- 1, 2, 3, 4, 5
# 	raceId INT -- 18
# 	driverId INT -- 1, 2, 3, 4, 5
# 	constructorId INT -- 1, 2, 3, 4
# 	number INT -- 22, 3, 7, 5, 23
# 	grid INT -- 1, 5, 7, 11, 3
# 	position INT -- 1, 2, 3, 4, 5
# 	positionText TEXT -- 1, 2, 3, 4, 5
# 	positionOrder INT -- 1, 2, 3, 4, 5
# 	points FLOAT -- 10.0, 8.0, 6.0, 5.0, 4.0
# 	laps INT -- 58
# 	time TEXT -- 1:34:50.616, +5.478, +8.163, +17.181, +18.014
# 	milliseconds INT -- 5690616, 5696094, 5698779, 5707797, 5708630
# 	fastestLap INT -- 39, 41, 58, 43
# 	rank INT -- 2, 3, 5, 7, 1
# 	fastestLapTime TEXT -- 1:27.452, 1:27.739, 1:28.090, 1:28.603, 1:27.418
# 	fastestLapSpeed TEXT -- 218.300, 217.586, 216.719, 215.464, 218.385
# 	statusId INT -- 1
# 	FOREIGN KEY (raceId) REFERENCES races (raceId)
# 	FOREIGN KEY (driverId) REFERENCES drivers (driverId)
# 	FOREIGN KEY (constructorId) REFERENCES constructors (constructorId)
# 	FOREIGN KEY (statusId) REFERENCES status (statusId)
# )
#
# What is the fastest lap number of the champion in 2009?
# in 2009 refers to year = 2009; Only the time of the champion shows in the format of "hour: minutes: seconds.millionsecond"
# {
#     "sql": "SELECT r.year, ds.driverId, res.fastestLap FROM driverStandings ds JOIN races r ON ds.raceId = r.raceId JOIN results res ON ds.driverId = res.driverId AND ds.raceId = res.raceId WHERE r.year = 2009 AND ds.position = 1 AND res.time LIKE '%:%:%.%' ORDER BY r.round DESC LIMIT 1"
# }
# here 1
# here 2
# here 3
# here 5
# processing row 6 of 500
# You are a principal data engineer. Help users write SQL queries for a SQLite database to answer their questions.
#
# For every user question, you'll be provided with context about their database in the following format:
# <table> (
#     <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
#     ...
#     <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
#     FOREIGN KEY (<column>) REFERENCES <table> (<column>)
# )
#
# Not all columns have descriptions or example values. Not all tables have foreign keys.
#
# You should only respond in this JSON format:
# {
#     "sql": "the sql that answers the user's question"
# }
# Examination (
# 	ID INT -- identification of the patient -- 14872, 48473, 102490, 108788, 122405
# 	"Examination Date" DATE -- 1997-05-27, 1992-12-21, 1995-04-20, 1997-05-06, 1998-04-02
# 	"aCL IgG" FLOAT -- 1.3, 4.3, 2.3, 0.0
# 	"aCL IgM" FLOAT -- 1.6, 4.6, 2.5, 0.0, 4.0
# 	ANA INT -- anti-nucleus antibody concentration -- 256, 0, 16, 4
# 	"ANA Pattern" TEXT -- anti-nucleus antibody concentration -- P, "P,S", S
# 	"aCL IgA" INT -- 0, 3, 4
# 	Diagnosis TEXT -- disease names -- "MCTD, AMI", SLE, PSS, "SLE, SjS, vertigo"
# 	KCT TEXT -- measure of degree of coagulation -- -
# 	RVVT TEXT -- measure of degree of coagulation -- -
# 	LAC TEXT -- measure of degree of coagulation -- -
# 	Symptoms TEXT -- other symptoms observed -- AMI
# 	Thrombosis INT -- degree of thrombosis -- 1, 0
# 	FOREIGN KEY (ID) REFERENCES Patient (ID)
# )
# Patient (
# 	ID INT -- identification of the patient -- 2110, 11408, 12052, 14872, 27654
# 	SEX TEXT -- Sex -- F
# 	Birthday DATE -- Birthday -- 1934-02-13, 1937-05-02, 1956-04-14, 1953-09-21, 1936-03-25
# 	Description DATE -- the first date when a patient data was recorded -- 1994-02-14, 1996-12-01, 1991-08-13, 1997-08-13
# 	"First Date" DATE -- 1993-02-10, 1973-01-01, 1992-02-03
# 	Admission TEXT -- patient was admitted to the hospital (+) or followed at the outpatient clinic (-) -- +
# 	Diagnosis TEXT -- disease names -- RA susp., PSS, SLE, MCTD, "RA, SLE susp"
# )
# Laboratory (
# 	ID INT -- identification of the patient -- 27654
# 	Date DATE -- Date of the laboratory tests (YYMMDD) -- 1991-09-11, 1991-09-17, 1991-09-19, 1991-09-20, 1991-09-21
# 	GOT INT -- AST glutamic oxaloacetic transaminase -- 34, 29, 26, 23
# 	GPT INT -- ALT glutamic pyruvic transaminase -- 36, 31, 22, 18
# 	LDH INT -- lactate dehydrogenase -- 567, 579, 684, 552
# 	ALP INT -- alkaliphophatase -- 166, 154, 138, 131
# 	TP FLOAT -- total protein -- 4.5, 5.1, 5.5, 4.2
# 	ALB FLOAT -- albumin -- 3.3, 3.4, 3.6, 2.9
# 	UA FLOAT -- uric acid -- 3.8, 4.2, 4.9, 4.8
# 	UN INT -- urea nitrogen -- 29, 36, 34, 22
# 	CRE FLOAT -- creatinine -- 0.8, 0.9, 0.7
# 	"T-BIL" FLOAT
# 	"T-CHO" INT
# 	TG INT -- triglyceride
# 	CPK INT -- creatinine phosphokinase -- 9, 10
# 	GLU INT -- blood glucose -- 88
# 	WBC FLOAT -- White blood cell -- 5.0, 10.4, 10.5, 10.3, 14.3
# 	RBC FLOAT -- Red blood cell -- 2.6, 2.9, 3.4, 3.2
# 	HGB FLOAT -- Hemoglobin -- 6.4, 6.7, 7.9, 6.1, 7.2
# 	HCT FLOAT -- Hematoclit -- 20.3, 21.6, 24.7, 19.3, 23.4
# 	PLT INT -- platelet -- 227, 242, 233, 201, 215
# 	PT FLOAT -- prothrombin time
# 	APTT INT -- activated partial prothrombin time
# 	FG FLOAT -- fibrinogen
# 	PIC INT
# 	TAT INT
# 	TAT2 INT
# 	"U-PRO" TEXT
# 	IGG INT -- Ig G -- 339, 771, 430
# 	IGA INT -- Ig A -- 145, 188, 118
# 	IGM INT -- Ig M -- 46, 132, 56
# 	CRP TEXT -- C-reactive protein -- 0.6, 2.7, 1.2
# 	RA TEXT -- Rhuematoid Factor
# 	RF TEXT -- RAHA
# 	C3 INT -- complement 3
# 	C4 INT -- complement 4
# 	RNP TEXT -- anti-ribonuclear protein
# 	SM TEXT -- anti-SM
# 	SC170 TEXT -- anti-scl70
# 	SSA TEXT -- anti-SSA
# 	SSB TEXT -- anti-SSB
# 	CENTROMEA TEXT -- anti-centromere
# 	DNA TEXT -- anti-DNA
# 	"DNA-II" INT
# 	FOREIGN KEY (ID) REFERENCES Patient (ID)
# )
#
# When was the medical information on patient number 48473 first documented, and what disease did she have?
# medical information first documented refers to Description; disease refers to diagnosis; patient number refers to id
# {
#     "sql": "SELECT Description, Diagnosis FROM Patient WHERE ID = 48473"
# }
# here 1
# here 2
# here 3
# here 5
# processing row 7 of 500
# You are a principal data engineer. Help users write SQL queries for a SQLite database to answer their questions.
#
# For every user question, you'll be provided with context about their database in the following format:
# <table> (
#     <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
#     ...
#     <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
#     FOREIGN KEY (<column>) REFERENCES <table> (<column>)
# )
#
# Not all columns have descriptions or example values. Not all tables have foreign keys.
#
# You should only respond in this JSON format:
# {
#     "sql": "the sql that answers the user's question"
# }
# event (
# 	event_id TEXT -- rec0Si5cQ4rJRVzd6, rec0akZnLLpGUloLH, rec0dZPcWXF0QjNnE
# 	event_name TEXT -- March Meeting, Officers meeting - January, Spring Elections
# 	event_date TEXT -- 2020-03-10T12:00:00, 2020-01-14T09:30:00, 2019-11-24T09:00:00
# 	type TEXT -- Meeting, Election, Game
# 	notes TEXT -- All active members can vote for new officers between 4pm-8pm.
# 	location TEXT -- MU 215, Campus Soccer/Lacrosse stadium
# 	status TEXT -- Open, Planning, Closed
# )
# major (
# 	major_id TEXT -- rec06DF6vZ1CyPKpc, rec09LedkREyskCNv, rec0Eanv576RhQllI
# 	major_name TEXT -- Outdoor Product Design and Development, Agricultural Communication
# 	department TEXT -- "School of Applied Sciences, Technology and Education"
# 	college TEXT -- College of Agriculture and Applied Sciences, College of Natural Resources
# )
# zip_code (
# 	zip_code INT -- 501, 544, 601, 602, 603
# 	type TEXT -- Unique, Standard
# 	city TEXT -- Holtsville, Adjuntas, Aguada, Aguadilla
# 	county TEXT -- Suffolk County, Adjuntas Municipio, Aguada Municipio
# 	state TEXT -- New York, Puerto Rico
# 	short_state TEXT -- NY, PR
# )
# "attendance" (
# 	link_to_event TEXT -- rec2N69DMcrqN9PJC
# 	link_to_member TEXT -- recD078PnS3x2doBe, recP6DJPyi5donvXL, rec28ORZgcm1dtqBZ
# 	FOREIGN KEY (link_to_event) REFERENCES event (event_id)
# 	FOREIGN KEY (link_to_member) REFERENCES member (member_id)
# )
# "budget" (
# 	budget_id TEXT -- rec0QmEc3cSQFQ6V2, rec1bG6HSft7XIvTP, rec1z6ISJU2HdIsVm
# 	category TEXT -- Advertisement, Food, Speaker Gifts
# 	spent FLOAT -- 67.81, 121.14, 20.2, 0.0
# 	remaining FLOAT -- 7.19, 28.86, -0.199999999999999, 25.0, 150.0
# 	amount INT -- 75, 150, 20, 25
# 	event_status TEXT -- Closed, Open
# 	link_to_event TEXT -- recI43CzsZ0Q625ma, recggMW2eyCYceNcy, recJ4Witp9tpjaugn
# 	FOREIGN KEY (link_to_event) REFERENCES event (event_id)
# )
# "expense" (
# 	expense_id TEXT -- rec017x6R3hQqkLAo, rec1nIjoZKTYayqZ6, rec1oMgNFt7Y0G40x
# 	expense_description TEXT -- "Post Cards, Posters", "Water, Cookies", Pizza, Posters
# 	expense_date TEXT -- 2019-08-20, 2019-10-08, 2019-09-10, 2019-10-10, 2019-11-19
# 	cost FLOAT -- 122.06, 20.2, 51.81, 67.81, 6.0
# 	approved TEXT -- true
# 	link_to_member TEXT -- rec4BLdZHS2Blfp4v, recro8T1MPMwRadVH, recD078PnS3x2doBe
# 	link_to_budget TEXT -- recvKTAWAFKkVNnXQ, recy8KY5bUdzF81vv, recwXIiKoBMjXJsGZ
# 	FOREIGN KEY (link_to_budget) REFERENCES budget (budget_id)
# 	FOREIGN KEY (link_to_member) REFERENCES member (member_id)
# )
# "income" (
# 	income_id TEXT -- rec0s9ZrO15zhzUeE, rec7f5XMQZexgtQJo, rec8BUJa8GXUjiglg
# 	date_received TEXT -- 2019-10-17, 2019-09-04, 2019-10-08, 2019-10-02, 2019-09-18
# 	amount INT -- 50
# 	source TEXT -- Dues
# 	notes TEXT
# 	link_to_member TEXT -- reccW7q1KkhSKZsea, recTjHY5xXhvkCdVT, recUdRhbhcEO1Hk5r
# 	FOREIGN KEY (link_to_member) REFERENCES member (member_id)
# )
# "member" (
# 	member_id TEXT -- rec1x5zBFIqoOuPW8, rec280Sk7o31iG0Tx, rec28ORZgcm1dtqBZ
# 	first_name TEXT -- Angela, Grant, Luisa, Randy, Connor
# 	last_name TEXT -- Sanders, Gilmour, Guidi, Woodard, Hilton
# 	email TEXT -- angela.sanders@lpu.edu, grant.gilmour@lpu.edu, luisa.guidi@lpu.edu
# 	position TEXT -- Member, Inactive
# 	t_shirt_size TEXT -- Medium, X-Large
# 	phone TEXT -- (651) 928-4507, 403-555-1310, 442-555-5882, 490-555-8460
# 	zip INT -- 55108, 29440, 10002, 8021, 48236
# 	link_to_major TEXT -- recxK3MHQFbR9J5uO, rec7BxKpjJ7bNph3O, recdIBgeU38UbV2sy
# 	FOREIGN KEY (link_to_major) REFERENCES major (major_id)
# 	FOREIGN KEY (zip) REFERENCES zip_code (zip_code)
# )
#
# Was each expense in October Meeting on October 8, 2019 approved?
# event_name = 'October Meeting' where event_date = '2019-10-08'; approved = True means expenses was approved; approved = False means expenses was not approved
# {
#     "sql": "SELECT e.event_name, ex.expense_description, ex.approved FROM expense ex JOIN budget b ON ex.link_to_budget = b.budget_id JOIN event e ON b.link_to_event = e.event_id WHERE e.event_name = 'October Meeting' AND e.event_date = '2019-10-08'"
# }
# here 1
# here 2
# Empty result set
# Corrected SQL: SELECT ex.expense_description, ex.approved FROM expense ex JOIN budget b ON ex.link_to_budget = b.budget_id WHERE b.link_to_event IN (SELECT event_id FROM event WHERE event_name = 'October Meeting' AND event_date = '2019-10-08')
# here 3
# here 5
# processing row 8 of 500
# You are a principal data engineer. Help users write SQL queries for a SQLite database to answer their questions.
#
# For every user question, you'll be provided with context about their database in the following format:
# <table> (
#     <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
#     ...
#     <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
#     FOREIGN KEY (<column>) REFERENCES <table> (<column>)
# )
#
# Not all columns have descriptions or example values. Not all tables have foreign keys.
#
# You should only respond in this JSON format:
# {
#     "sql": "the sql that answers the user's question"
# }
# alignment (
# 	id INT -- the unique identifier of the alignment -- 1, 2, 3, 4
# 	alignment TEXT -- the alignment of the superhero -- Good, Bad, Neutral, N/A
# )
# attribute (
# 	id INT -- the unique identifier of the attribute -- 1, 2, 3, 4, 5
# 	attribute_name TEXT -- the attribute -- Intelligence, Strength, Speed, Durability, Power
# )
# colour (
# 	id INT -- the unique identifier of the color -- 1, 2, 3, 4, 5
# 	colour TEXT -- the color of the superhero's skin/eye/hair/etc -- No Colour, Amber, Auburn, Black, Black/Blue
# )
# gender (
# 	id INT -- the unique identifier of the gender -- 1, 2, 3
# 	gender TEXT -- the gender of the superhero -- Male, Female, N/A
# )
# publisher (
# 	id INT -- the unique identifier of the publisher -- 1, 2, 3, 4, 5
# 	publisher_name TEXT -- the name of the publisher -- , ABC Studios, Dark Horse Comics, DC Comics, George Lucas
# )
# race (
# 	id INT -- the unique identifier of the race -- 1, 2, 3, 4, 5
# 	race TEXT -- the race of the superhero -- -, Alien, Alpha, Amazon, Android
# )
# superhero (
# 	id INT -- the unique identifier of the superhero -- 1, 2, 3, 4, 5
# 	superhero_name TEXT -- the name of the superhero -- 3-D Man, A-Bomb, Abe Sapien, Abin Sur, Abomination
# 	full_name TEXT -- the full name of the superhero -- Charles Chandler, Richard Milhouse Jones, Abraham Sapien
# 	gender_id INT -- the id of the superhero's gender -- 1
# 	eye_colour_id INT -- the id of the superhero's eye color -- 9, 33, 7, 14
# 	hair_colour_id INT -- the id of the superhero's hair color -- 13, 1
# 	skin_colour_id INT -- the id of the superhero's skin color -- 1, 7, 23
# 	race_id INT -- the id of the superhero's race -- 1, 24, 33, 55, 28
# 	publisher_id INT -- the id of the publisher -- 13, 3, 4
# 	alignment_id INT -- the id of the superhero's alignment -- 1, 2
# 	height_cm INT -- the height of the superhero -- 188, 203, 191, 185
# 	weight_kg INT -- the weight of the superhero -- 90, 441, 65
# 	FOREIGN KEY (alignment_id) REFERENCES alignment (id)
# 	FOREIGN KEY (eye_colour_id) REFERENCES colour (id)
# 	FOREIGN KEY (gender_id) REFERENCES gender (id)
# 	FOREIGN KEY (hair_colour_id) REFERENCES colour (id)
# 	FOREIGN KEY (publisher_id) REFERENCES publisher (id)
# 	FOREIGN KEY (race_id) REFERENCES race (id)
# 	FOREIGN KEY (skin_colour_id) REFERENCES colour (id)
# )
# hero_attribute (
# 	hero_id INT -- the id of the hero
# Maps to superhero(id) -- 1, 2, 3, 4, 5
# 	attribute_id INT -- the id of the attribute
# Maps to attribute(id) -- 1
# 	attribute_value INT -- the attribute value -- 80, 75, 95, 85
# 	FOREIGN KEY (attribute_id) REFERENCES attribute (id)
# 	FOREIGN KEY (hero_id) REFERENCES superhero (id)
# )
# superpower (
# 	id INT -- the unique identifier of the superpower -- 1, 2, 3, 4, 5
# 	power_name TEXT -- the superpower name -- Agility, Accelerated Healing, Lantern Power Ring
# )
# hero_power (
# 	hero_id INT -- the id of the hero
# Maps to superhero(id) -- 1, 2
# 	power_id INT -- the id of the power
# Maps to superpower(id) -- 1, 18, 26, 31, 2
# 	FOREIGN KEY (hero_id) REFERENCES superhero (id)
# 	FOREIGN KEY (power_id) REFERENCES superpower (id)
# )
#
# How many heroes have stealth power?
# stealth power refers to power_name = 'stealth';
# {
#     "sql": "SELECT COUNT(DISTINCT hero_id) AS num_heroes_with_stealth FROM hero_power JOIN superpower ON hero_power.power_id = superpower.id WHERE superpower.power_name = 'stealth'"
# }
# here 1
# here 2
# here 3
# here 5
# processing row 9 of 500
# You are a principal data engineer. Help users write SQL queries for a SQLite database to answer their questions.
#
# For every user question, you'll be provided with context about their database in the following format:
# <table> (
#     <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
#     ...
#     <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
#     FOREIGN KEY (<column>) REFERENCES <table> (<column>)
# )
#
# Not all columns have descriptions or example values. Not all tables have foreign keys.
#
# You should only respond in this JSON format:
# {
#     "sql": "the sql that answers the user's question"
# }
# "cards" (
# 	id INT -- 1, 2, 3, 4, 5
# 	artist TEXT -- Pete Venters, Volkan Baǵa, Justin Sweet, Matthew D. Wilson
# 	asciiName TEXT
# 	availability TEXT -- "mtgo,paper"
# 	borderColor TEXT -- black
# 	cardKingdomFoilId TEXT -- 123094, 123095
# 	cardKingdomId TEXT -- 122719, 122720, 122725, 122726, 122727
# 	colorIdentity TEXT -- W
# 	colorIndicator TEXT
# 	colors TEXT -- W
# 	convertedManaCost FLOAT -- 7.0, 5.0, 4.0, 1.0
# 	duelDeck TEXT
# 	edhrecRank INT -- 15650, 12702, 11081, 12901, 3988
# 	faceConvertedManaCost FLOAT
# 	faceName TEXT
# 	flavorName TEXT
# 	flavorText TEXT -- Every tear shed is a drop of immortality., The perfect antidote for a tightly packed formation.
# 	frameEffects TEXT
# 	frameVersion TEXT -- 2003
# 	hand TEXT
# 	hasAlternativeDeckLimit INT -- 0
# 	hasContentWarning INT -- 0
# 	hasFoil INT -- 0, 1
# 	hasNonFoil INT -- 1
# 	isAlternative INT -- 0
# 	isFullArt INT -- 0
# 	isOnlineOnly INT -- 0
# 	isOversized INT -- 0
# 	isPromo INT -- 0
# 	isReprint INT -- 1
# 	isReserved INT -- 0
# 	isStarter INT -- 0
# 	isStorySpotlight INT -- 0
# 	isTextless INT -- 0
# 	isTimeshifted INT -- 0
# 	keywords TEXT -- First strike, Flying
# 	layout TEXT -- normal
# 	leadershipSkills TEXT
# 	life TEXT
# 	loyalty TEXT
# 	manaCost TEXT -- {5}{W}{W}, {4}{W}, {3}{W}, {W}
# 	mcmId TEXT -- 16165, 16166, 16171, 16172, 16173
# 	mcmMetaId TEXT -- 156, 176, 368, 423, 432
# 	mtgArenaId TEXT
# 	mtgjsonV4Id TEXT -- ad41be73-582f-58ed-abd4-a88c1f616ac3, 9eb2e54c-a12b-5e88-a9c0-d8c84c52d59c
# 	mtgoFoilId TEXT -- 27501, 26993, 27473, 27327, 27095
# 	mtgoId TEXT -- 27500, 26992, 27472, 27326, 27094
# 	multiverseId TEXT -- 130550, 129465, 129470, 129477, 132106
# 	name TEXT -- Ancestor"s Chosen, Angel of Mercy, Aven Cloudchaser
# 	number TEXT -- 1, 2, 7, 8, 9
# 	originalReleaseDate TEXT
# 	originalText TEXT -- First strike (This creature deals combat damage before creatures without first strike.) When Ancesto
# 	originalType TEXT -- Creature - Human Cleric, Creature - Angel, Creature - Bird Soldier
# 	otherFaceIds TEXT
# 	power TEXT -- 4, 3, 2
# 	printings TEXT -- "10E,JUD,UMA", "10E,8ED,9ED,DDC,DVD,IMA,INV,JMP,MB1,P02,PS11,PSAL,S99"
# 	promoTypes TEXT
# 	purchaseUrls TEXT -- "{\"cardKingdom\": \"https://mtgjson.com/links/9fb51af0ad6f0736\", \"cardmarket\": \"https://mtgjson.com/lin"
# 	rarity TEXT -- uncommon, common
# 	scryfallId TEXT -- 7a5cd03c-4227-4551-aa4b-7d119f0468b5, 8f7980d4-da43-4d6d-ad16-14b8a34ae91d
# 	scryfallIllustrationId TEXT -- be2f7173-c8b7-4172-a388-9b2c6b3c16e5, e4d6c53f-e936-4be8-8b70-47c2be863b20
# 	scryfallOracleId TEXT -- fc2ccab7-cab1-4463-b73d-898070136d74, a2daaf32-dbfe-4618-892e-0da24f63a44a
# 	setCode TEXT -- 10E
# 	side TEXT
# 	subtypes TEXT -- "Human,Cleric", Angel, "Bird,Soldier", "Human,Rebel"
# 	supertypes TEXT
# 	tcgplayerProductId TEXT -- 15032, 15033, 15045, 15048, 15049
# 	text TEXT -- First strike (This creature deals combat damage before creatures without first strike.) When Ancesto
# 	toughness TEXT -- 4, 3, 2
# 	type TEXT -- Creature — Human Cleric, Creature — Angel, Creature — Bird Soldier
# 	types TEXT -- Creature, Instant
# 	uuid TEXT -- 5f8287b1-5bb6-5f4c-ad17-316a40d5bb0c, 57aaebc1-850c-503d-9f6e-bb8d00d8bf7c
# 	variations TEXT -- b7c19924-b4bf-56fc-aa73-f586e940bd42, 8fd4e2eb-3eb4-50ea-856b-ef638fa47f8a
# 	watermark TEXT
# )
# "foreign_data" (
# 	id INT -- unique id number identifying this row of data -- 1, 2, 3, 4, 5
# 	flavorText TEXT -- The foreign flavor text of the card. -- "\u201eEs ist der Wille aller, und meine Hand, die ihn ausf\u00fchrt.\""
# 	language TEXT -- The foreign language of card. -- German, Spanish, French, Italian, Japanese
# 	multiverseid INT -- The foreign multiverse identifier of the card. -- 148411, 150317, 149934, 148794, 148028
# 	name TEXT -- The foreign name of the card. -- Ausgewählter der Ahnfrau, Elegido de la Antepasada
# 	text TEXT -- The foreign text ruling of the card. -- Erstschlag (Diese Kreatur fügt Kampfschaden vor Kreaturen ohne Erstschlag zu.) Wenn der Ausgewählte
# 	type TEXT -- The foreign type of the card. Includes any supertypes and subtypes. -- "Kreatur \u2014 Mensch, Kleriker", Criatura — Clérigo humano
# 	uuid TEXT -- 5f8287b1-5bb6-5f4c-ad17-316a40d5bb0c
# )
# "legalities" (
# 	id INT -- 1, 2, 3, 4, 5
# 	format TEXT -- commander, duel, legacy, modern, penny
# 	status TEXT -- Legal
# 	uuid TEXT -- 5f8287b1-5bb6-5f4c-ad17-316a40d5bb0c
# )
# "sets" (
# 	id INT -- 1, 2, 3, 4, 5
# 	baseSetSize INT -- 383, 302, 332, 306, 378
# 	block TEXT -- Core Set
# 	booster TEXT -- "{\"default\": {\"boosters\": [{\"contents\": {\"basic\": 1, \"common\": 10, \"rare\": 1, \"uncommon\": 3}, \"weight"
# 	code TEXT -- 10E, 2ED, 2XM, 3ED, 4BB
# 	isFoilOnly INT -- 0
# 	isForeignOnly INT -- 0, 1
# 	isNonFoilOnly INT -- 0, 1
# 	isOnlineOnly INT -- 0
# 	isPartialPreview INT -- 0
# 	keyruneCode TEXT -- 10E, 2ED, 2XM, 3ED, 4ED
# 	mcmId INT -- 74, 3204
# 	mcmIdExtras INT -- 3209
# 	mcmName TEXT -- Tenth Edition, Double Masters
# 	mtgoCode TEXT -- 10E, 2XM
# 	name TEXT -- Tenth Edition, Unlimited Edition, Double Masters
# 	parentCode TEXT
# 	releaseDate DATE -- 2007-07-13, 1993-12-01, 2020-08-07, 1994-04-01, 1995-04-01
# 	tcgplayerGroupId INT -- 1, 115, 2655, 97
# 	totalSetSize INT -- 508, 302, 384, 306, 378
# 	type TEXT -- core, masters
# )
# "set_translations" (
# 	id INT -- 1, 2, 3, 4, 5
# 	language TEXT -- Chinese Simplified, Chinese Traditional, French, German
# 	setCode TEXT -- 10E
# 	translation TEXT -- 核心系列第十版, Dixième édition, Hauptset Zehnte Edition
# )
# "rulings" (
# 	id INT -- 1, 2, 3, 4, 5
# 	date DATE -- 2007-07-15, 2007-02-01, 2010-08-15
# 	text TEXT -- "You draw the card when Bandage resolves, not when the damage is actually prevented."
# 	uuid TEXT -- 6d268c95-c176-5766-9a46-c14f739aba1c, 56f4935b-f6c5-59b9-88bf-9bcce20247ce
# )
#
# Which set is not available outside of the United States and has foil cards with Japanese writing on them? Please include the set ID in your response.
# available outside of the United States refers to isForeignOnly = 1; has foil cards refers to isFoilOnly = 1; with Japanese writing on them refers to language = 'Japanese'
# {
#     "sql": "SELECT sets.id FROM sets JOIN foreign_data ON sets.code = foreign_data.multiverseid WHERE sets.isForeignOnly = 1 AND sets.isFoilOnly = 1 AND foreign_data.language = 'Japanese'"
# }
# here 1
# here 2
# Empty result set
# Corrected SQL: SELECT id FROM sets WHERE isForeignOnly = 1 AND isFoilOnly = 1
# here 3
# here 5
# processing row 10 of 500
# You are a principal data engineer. Help users write SQL queries for a SQLite database to answer their questions.
#
# For every user question, you'll be provided with context about their database in the following format:
# <table> (
#     <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
#     ...
# ...
# 	type TEXT -- Creature — Human Cleric, Creature — Angel, Creature — Bird Soldier
# 	types TEXT -- Creature, Instant
# 	uuid TEXT -- 5f8287b1-5bb6-5f4c-ad17-316a40d5bb0c, 57aaebc1-850c-503d-9f6e-bb8d00d8bf7c
# 	variations TEXT -- b7c19924-b4bf-56fc-aa73-f586e940bd42, 8fd4e2eb-3eb4-50ea-856b-ef638fa47f8a
# 	watermark TEXT
# )
# "foreign_data" (
# 	id INT -- unique id number identifying this row of data -- 1, 2, 3, 4, 5
# 	flavorText TEXT -- The foreign flavor text of the card. -- "\u201eEs ist der Wille aller, und meine Hand, die ihn ausf\u00fchrt.\""
# 	language TEXT -- The foreign language of card. -- German, Spanish, French, Italian, Japanese
# 	multiverseid INT -- The foreign multiverse identifier of the card. -- 148411, 150317, 149934, 148794, 148028
# 	name TEXT -- The foreign name of the card. -- Ausgewählter der Ahnfrau, Elegido de la Antepasada
# 	text TEXT -- The foreign text ruling of the card. -- Erstschlag (Diese Kreatur fügt Kampfschaden vor Kreaturen ohne Erstschlag zu.) Wenn der Ausgewählte
# 	type TEXT -- The foreign type of the card. Includes any supertypes and subtypes. -- "Kreatur \u2014 Mensch, Kleriker", Criatura — Clérigo humano
# 	uuid TEXT -- 5f8287b1-5bb6-5f4c-ad17-316a40d5bb0c
# )
# "legalities" (
# 	id INT -- 1, 2, 3, 4, 5
# 	format TEXT -- commander, duel, legacy, modern, penny
# 	status TEXT -- Legal
# 	uuid TEXT -- 5f8287b1-5bb6-5f4c-ad17-316a40d5bb0c
# )
# "sets" (
# 	id INT -- 1, 2, 3, 4, 5
# 	baseSetSize INT -- 383, 302, 332, 306, 378
# 	block TEXT -- Core Set
# 	booster TEXT -- "{\"default\": {\"boosters\": [{\"contents\": {\"basic\": 1, \"common\": 10, \"rare\": 1, \"uncommon\": 3}, \"weight"
# 	code TEXT -- 10E, 2ED, 2XM, 3ED, 4BB
# 	isFoilOnly INT -- 0
# 	isForeignOnly INT -- 0, 1
# 	isNonFoilOnly INT -- 0, 1
# 	isOnlineOnly INT -- 0
# 	isPartialPreview INT -- 0
# 	keyruneCode TEXT -- 10E, 2ED, 2XM, 3ED, 4ED
# 	mcmId INT -- 74, 3204
# 	mcmIdExtras INT -- 3209
# 	mcmName TEXT -- Tenth Edition, Double Masters
# 	mtgoCode TEXT -- 10E, 2XM
# 	name TEXT -- Tenth Edition, Unlimited Edition, Double Masters
# 	parentCode TEXT
# 	releaseDate DATE -- 2007-07-13, 1993-12-01, 2020-08-07, 1994-04-01, 1995-04-01
# 	tcgplayerGroupId INT -- 1, 115, 2655, 97
# 	totalSetSize INT -- 508, 302, 384, 306, 378
# 	type TEXT -- core, masters
# )
# "set_translations" (
# 	id INT -- 1, 2, 3, 4, 5
# 	language TEXT -- Chinese Simplified, Chinese Traditional, French, German
# 	setCode TEXT -- 10E
# 	translation TEXT -- 核心系列第十版, Dixième édition, Hauptset Zehnte Edition
# )
# "rulings" (
# 	id INT -- 1, 2, 3, 4, 5
# 	date DATE -- 2007-07-15, 2007-02-01, 2010-08-15
# 	text TEXT -- "You draw the card when Bandage resolves, not when the damage is actually prevented."
# 	uuid TEXT -- 6d268c95-c176-5766-9a46-c14f739aba1c, 56f4935b-f6c5-59b9-88bf-9bcce20247ce
# )
#
# How many cards with print rarity have ruling text printed on 10/01/2009?
# with print rarity refers to rarity = 'rare'; on 10/01/2009 refers to date = '2009-01-10'
# {
#     "sql": "SELECT COUNT(DISTINCT cards.id) FROM cards JOIN rulings ON cards.uuid = rulings.uuid WHERE cards.rarity = 'rare' AND rulings.date = '2009-01-10'"
# }
# here 1
# here 2
# here 3
# here 5
# processing row 498 of 500
# You are a principal data engineer. Help users write SQL queries for a SQLite database to answer their questions.
#
# For every user question, you'll be provided with context about their database in the following format:
# <table> (
#     <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
#     ...
#     <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
#     FOREIGN KEY (<column>) REFERENCES <table> (<column>)
# )
#
# Not all columns have descriptions or example values. Not all tables have foreign keys.
#
# You should only respond in this JSON format:
# {
#     "sql": "the sql that answers the user's question"
# }
# frpm (
# 	CDSCode TEXT -- CDSCode -- 01100170109835, 01100170112607, 01100170118489, 01100170123968
# 	"Academic Year" TEXT -- 2014-2015
# 	"County Code" TEXT -- 01
# 	"District Code" INT -- 10017
# 	"School Code" TEXT -- 0109835, 0112607, 0118489, 0123968, 0124172
# 	"County Name" TEXT -- Alameda
# 	"District Name" TEXT -- Alameda County Office of Education
# 	"School Name" TEXT -- FAME Public Charter, Envision Academy for Arts & Technology
# 	"District Type" TEXT -- County Office of Education (COE)
# 	"School Type" TEXT -- K-12 Schools (Public), High Schools (Public), Elementary Schools (Public)
# 	"Educational Option Type" TEXT -- Traditional
# 	"NSLP Provision Status" TEXT -- Breakfast Provision 2
# 	"Charter School (Y/N)" INT -- 1
# 	"Charter School Number" TEXT -- 0728, 0811, 1049, 1284, 1296
# 	"Charter Funding Type" TEXT -- Directly funded
# 	IRC INT -- 1
# 	"Low Grade" TEXT -- K, 9
# 	"High Grade" TEXT -- 12, 8
# 	"Enrollment (K-12)" FLOAT -- 1087.0, 395.0, 244.0, 191.0, 257.0
# 	"Free Meal Count (K-12)" FLOAT -- 565.0, 186.0, 134.0, 113.0, 14.0
# 	"Percent (%) Eligible Free (K-12)" FLOAT -- 0.519779208831647, 0.470886075949367, 0.549180327868853
# 	"FRPM Count (K-12)" FLOAT -- 715.0, 186.0, 175.0, 139.0, 21.0
# 	"Percent (%) Eligible FRPM (K-12)" FLOAT -- 0.657773689052438, 0.470886075949367, 0.717213114754098
# 	"Enrollment (Ages 5-17)" FLOAT -- 1070.0, 376.0, 230.0, 190.0, 257.0
# 	"Free Meal Count (Ages 5-17)" FLOAT -- 553.0, 182.0, 128.0, 113.0, 14.0
# 	"Percent (%) Eligible Free (Ages 5-17)" FLOAT -- 0.516822429906542, 0.484042553191489, 0.556521739130435
# 	"FRPM Count (Ages 5-17)" FLOAT -- 702.0, 182.0, 168.0, 139.0, 21.0
# 	"Percent (%) Eligible FRPM (Ages 5-17)" FLOAT -- 0.65607476635514, 0.484042553191489, 0.730434782608696
# 	"2013-14 CALPADS Fall 1 Certification Status" INT
# 	FOREIGN KEY (CDSCode) REFERENCES schools (CDSCode)
# )
# satscores (
# 	cds TEXT -- 1100170000000, 1100170109835, 1100170112607, 1100170118489
# 	rtype TEXT -- D, S
# 	sname TEXT -- FAME Public Charter, Envision Academy for Arts & Technology
# 	dname TEXT -- Alameda County Office of Education, Alameda Unified
# 	cname TEXT -- Alameda
# 	enroll12 INT -- 398, 62, 75, 61, 922
# 	NumTstTakr INT -- 88, 17, 71, 0, 544
# 	AvgScrRead INT -- 418, 503, 397, 521
# 	AvgScrMath INT -- 418, 546, 387
# 	AvgScrWrite INT -- 417, 505, 395, 519
# 	NumGE1500 INT -- 14, 9, 5, 333
# 	FOREIGN KEY (cds) REFERENCES schools (CDSCode)
# )
# schools (
# 	CDSCode TEXT -- 01100170000000, 01100170109835, 01100170112607, 01100170118489
# 	NCESDist TEXT -- 0691051
# 	NCESSchool TEXT -- 10546, 10947, 12283, 12844
# 	StatusType TEXT -- Active, Closed
# 	County TEXT -- Alameda
# 	District TEXT -- Alameda County Office of Education
# 	School TEXT -- FAME Public Charter, Envision Academy for Arts & Technology
# 	Street TEXT -- 313 West Winton Avenue, "39899 Balentine Drive, Suite 335"
# 	StreetAbr TEXT -- 313 West Winton Ave., "39899 Balentine Dr., Ste. 335"
# 	City TEXT -- Hayward, Newark, Oakland, Berkeley
# 	Zip TEXT -- 94544-1136, 94560-5359, 94612-3355, 94703-1414, 94606-4903
# 	State TEXT -- CA
# 	MailStreet TEXT -- 313 West Winton Avenue, "39899 Balentine Drive, Suite 335"
# 	MailStrAbr TEXT -- 313 West Winton Ave., "39899 Balentine Dr., Ste. 335"
# 	MailCity TEXT -- Hayward, Newark, Oakland
# 	MailZip TEXT -- 94544-1136, 94560-5359, 94612, 94606, 94606-4903
# 	MailState TEXT -- CA
# 	Phone TEXT -- (510) 887-0152, (510) 596-8901, (510) 686-4131
# 	Ext TEXT
# 	Website TEXT -- www.acoe.org, www.envisionacademy.org/, www.aspirepublicschools.org
# 	OpenDate DATE -- 2005-08-29, 2006-08-28, 2008-08-21, 2011-08-22
# 	ClosedDate DATE -- 2015-07-31, 2015-06-30
# 	Charter INT -- 1
# 	CharterNum TEXT -- 0728, 0811, 1049, 1284
# 	FundingType TEXT -- Directly funded
# 	DOC TEXT -- 00
# 	DOCType TEXT -- County Office of Education (COE)
# 	SOC TEXT -- 65, 66, 60
# 	SOCType TEXT -- K-12 Schools (Public), High Schools (Public), Elementary Schools (Public)
# 	EdOpsCode TEXT -- TRAD
# 	EdOpsName TEXT -- Traditional
# 	EILCode TEXT -- ELEMHIGH, HS, ELEM
# 	EILName TEXT -- Elementary-High Combination, High School, Elementary
# 	GSoffered TEXT -- K-12, 9-12, K-8
# 	GSserved TEXT -- K-12, 9-12, K-7
# 	Virtual TEXT -- P, N
# 	Magnet INT -- 0
# 	Latitude FLOAT -- 37.658212, 37.521436, 37.80452, 37.868991, 37.784648
# 	Longitude FLOAT -- -122.09713, -121.99391, -122.26815, -122.27844, -122.23863
# 	AdmFName1 TEXT -- L Karen, Laura, Clifford
# 	AdmLName1 TEXT -- Monroe, Robell, Thompson
# 	AdmEmail1 TEXT -- lkmonroe@acoe.org, laura@envisionacademy.org, cliffordt@communityschoolforcreativeeducation.org
# 	AdmFName2 TEXT
# 	AdmLName2 TEXT
# 	AdmEmail2 TEXT
# 	AdmFName3 TEXT
# 	AdmLName3 TEXT
# 	AdmEmail3 TEXT
# 	LastUpdate DATE -- 2015-06-23, 2015-09-01, 2015-06-18, 2015-07-01, 2016-07-18
# )
#
# What is the total number of non-chartered schools in the county of Los Angeles with a percent (%) of eligible free meals for grades 1 through 12 that is less than 0.18%?
# non-chartered schools refer to schools whose Charter = 0; K-12 means grades 1 through 12; percent of eligible free rate for K-12 = `Free Meal Count (K-12)` * 100 / `Enrollment (K-12)`
# {
#     "sql": "SELECT COUNT(*) AS total_non_chartered_schools FROM schools JOIN frpm ON schools.CDSCode = frpm.CDSCode WHERE schools.Charter = 0 AND schools.County = 'Los Angeles' AND (frpm.\"Free Meal Count (K-12)\" * 100 / frpm.\"Enrollment (K-12)\") < 0.18"
# }
# here 1
# here 2
# here 3
# here 5
# processing row 499 of 500
# You are a principal data engineer. Help users write SQL queries for a SQLite database to answer their questions.
#
# For every user question, you'll be provided with context about their database in the following format:
# <table> (
#     <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
#     ...
#     <column> <data_type> -- <column_description> -- <example_value>, <example_value>, ...
#     FOREIGN KEY (<column>) REFERENCES <table> (<column>)
# )
#
# Not all columns have descriptions or example values. Not all tables have foreign keys.
#
# You should only respond in this JSON format:
# {
#     "sql": "the sql that answers the user's question"
# }
# alignment (
# 	id INT -- the unique identifier of the alignment -- 1, 2, 3, 4
# 	alignment TEXT -- the alignment of the superhero -- Good, Bad, Neutral, N/A
# )
# attribute (
# 	id INT -- the unique identifier of the attribute -- 1, 2, 3, 4, 5
# 	attribute_name TEXT -- the attribute -- Intelligence, Strength, Speed, Durability, Power
# )
# colour (
# 	id INT -- the unique identifier of the color -- 1, 2, 3, 4, 5
# 	colour TEXT -- the color of the superhero's skin/eye/hair/etc -- No Colour, Amber, Auburn, Black, Black/Blue
# )
# gender (
# 	id INT -- the unique identifier of the gender -- 1, 2, 3
# 	gender TEXT -- the gender of the superhero -- Male, Female, N/A
# )
# publisher (
# 	id INT -- the unique identifier of the publisher -- 1, 2, 3, 4, 5
# 	publisher_name TEXT -- the name of the publisher -- , ABC Studios, Dark Horse Comics, DC Comics, George Lucas
# )
# race (
# 	id INT -- the unique identifier of the race -- 1, 2, 3, 4, 5
# 	race TEXT -- the race of the superhero -- -, Alien, Alpha, Amazon, Android
# )
# superhero (
# 	id INT -- the unique identifier of the superhero -- 1, 2, 3, 4, 5
# 	superhero_name TEXT -- the name of the superhero -- 3-D Man, A-Bomb, Abe Sapien, Abin Sur, Abomination
# 	full_name TEXT -- the full name of the superhero -- Charles Chandler, Richard Milhouse Jones, Abraham Sapien
# 	gender_id INT -- the id of the superhero's gender -- 1
# 	eye_colour_id INT -- the id of the superhero's eye color -- 9, 33, 7, 14
# 	hair_colour_id INT -- the id of the superhero's hair color -- 13, 1
# 	skin_colour_id INT -- the id of the superhero's skin color -- 1, 7, 23
# 	race_id INT -- the id of the superhero's race -- 1, 24, 33, 55, 28
# 	publisher_id INT -- the id of the publisher -- 13, 3, 4
# 	alignment_id INT -- the id of the superhero's alignment -- 1, 2
# 	height_cm INT -- the height of the superhero -- 188, 203, 191, 185
# 	weight_kg INT -- the weight of the superhero -- 90, 441, 65
# 	FOREIGN KEY (alignment_id) REFERENCES alignment (id)
# 	FOREIGN KEY (eye_colour_id) REFERENCES colour (id)
# 	FOREIGN KEY (gender_id) REFERENCES gender (id)
# 	FOREIGN KEY (hair_colour_id) REFERENCES colour (id)
# 	FOREIGN KEY (publisher_id) REFERENCES publisher (id)
# 	FOREIGN KEY (race_id) REFERENCES race (id)
# 	FOREIGN KEY (skin_colour_id) REFERENCES colour (id)
# )
# hero_attribute (
# 	hero_id INT -- the id of the hero
# Maps to superhero(id) -- 1, 2, 3, 4, 5
# 	attribute_id INT -- the id of the attribute
# Maps to attribute(id) -- 1
# 	attribute_value INT -- the attribute value -- 80, 75, 95, 85
# 	FOREIGN KEY (attribute_id) REFERENCES attribute (id)
# 	FOREIGN KEY (hero_id) REFERENCES superhero (id)
# )
# superpower (
# 	id INT -- the unique identifier of the superpower -- 1, 2, 3, 4, 5
# 	power_name TEXT -- the superpower name -- Agility, Accelerated Healing, Lantern Power Ring
# )
# hero_power (
# 	hero_id INT -- the id of the hero
# Maps to superhero(id) -- 1, 2
# 	power_id INT -- the id of the power
# Maps to superpower(id) -- 1, 18, 26, 31, 2
# 	FOREIGN KEY (hero_id) REFERENCES superhero (id)
# 	FOREIGN KEY (power_id) REFERENCES superpower (id)
# )
#
# Provide the name of superhero with superhero ID 294.
# name of superhero refers to superhero_name; superhero ID 294 refers to superhero.id = 294;
# {
#     "sql": "SELECT superhero_name FROM superhero WHERE id = 294"
# }
# here 1
# here 2
# here 3
# here 5
#                                          user_prompt                  db_id  \
# 0  Examination (\n\tID INT -- identification of t...  thrombosis_prediction
# 1  frpm (\n\tCDSCode TEXT -- CDSCode -- 011001701...     california_schools
# 2  "atom" (\n\t"atom_id" TEXT -- the unique id of...             toxicology
# 3  Examination (\n\tID INT -- identification of t...  thrombosis_prediction
# 4  badges (\n\tId INT -- 1, 2, 3, 4, 5\n\tUserId ...     codebase_community
#
#                             ideal_assistant_response  \
# 0  SELECT DISTINCT T1.ID, T1.SEX, T1.Birthday FRO...
# 1  SELECT GSserved FROM schools WHERE City = 'Ade...
# 2  SELECT COUNT(T.molecule_id) FROM molecule AS T...
# 3  SELECT COUNT(DISTINCT T1.ID) FROM Patient AS T...
# 4  SELECT COUNT(id) FROM users WHERE Reputation >...
#
#                                             question  \
# 0  List ID, sex and date of birth of patient whos...
# 1  What is the most common type of grade span ser...
# 2  Calculate the total carcinogenic molecules for...
# 3  Excluding all P only ANA Pattern patients, how...
# 4  How many users whose reputations are higher th...
#
#                                           embeddings similar_questions  \
# 0  [0.015778781846165657, 0.005091146100312471, -...                []
# 1  [0.014656159095466137, 0.02713850326836109, -0...                []
# 2  [-0.026426946744322777, -0.053564295172691345,...                []
# 3  [-0.024667911231517792, 0.005138586275279522, ...                []
# 4  [-0.015890464186668396, -0.012033837847411633,...                []
#
#                                first_predicted_query  \
# 0  SELECT Patient.ID, Patient.SEX, Patient.Birthd...
# 1  SELECT GSserved, COUNT(*) AS count FROM school...
# 2  SELECT COUNT(*) AS total_carcinogenic_molecule...
# 3  SELECT COUNT(DISTINCT Patient.ID) FROM Patient...
# 4  SELECT COUNT(*) FROM users WHERE Reputation > ...
#
#                                final_predicted_query  \
# 0  SELECT Patient.ID, Patient.SEX, Patient.Birthd...
# 1  SELECT GSserved, COUNT(*) AS count FROM school...
# 2  SELECT COUNT(*) AS total_carcinogenic_molecule...
# 3  SELECT COUNT(DISTINCT Patient.ID) FROM Patient...
# 4  SELECT COUNT(*) FROM users WHERE Reputation > ...
#
#                                        predicted_res  execution_accuracy  \
# 0  {(4862013, F, 1964-01-29), (2355809, F, 1938-0...                   1
# 1                                         {(K-6, 5)}                   0
# 2                                             {(7,)}                   1
# 3                                             {(3,)}                   1
# 4                                            {(44,)}                   1
#
#                                     formatted_string
# 0  SELECT Patient.ID, Patient.SEX, Patient.Birthd...
# 1  SELECT GSserved, COUNT(*) AS count FROM school...
# 2  SELECT COUNT(*) AS total_carcinogenic_molecule...
# 3  SELECT COUNT(DISTINCT Patient.ID) FROM Patient...
# 4  SELECT COUNT(*) FROM users WHERE Reputation > ...

# %%
df_reference_questions[df_reference_questions['question'].str.contains('How many word that has')].iloc[0]#['question']
# Out:
# db_id                                            language_corpus
# question       How many word that has number of different wor...
# evidence                                            This is not;
# SQL            SELECT COUNT(T2.wid) FROM pages AS T1 INNER JO...
# embeddings     [-0.009390588849782944, 0.0025102547369897366,...
# ddl            langs (\n\tlid INT -- 1\n\tlang TEXT -- ca\n\t...
# user_prompt    langs (\n\tlid INT -- 1\n\tlang TEXT -- ca\n\t...
# Name: 5779, dtype: object

# %%
row = df_pred[df_pred['execution_accuracy'] == 0].iloc[-2]
# print row's index
print(row.name)
print(row['user_prompt'])
print(row['ideal_assistant_response'])
print(row['first_predicted_query'])
# Out:
# 495
# frpm (
# 	CDSCode TEXT -- CDSCode -- 01100170109835, 01100170112607, 01100170118489, 01100170123968
# 	"Academic Year" TEXT -- 2014-2015
# 	"County Code" TEXT -- 01
# 	"District Code" INT -- 10017
# 	"School Code" TEXT -- 0109835, 0112607, 0118489, 0123968, 0124172
# 	"County Name" TEXT -- Alameda
# 	"District Name" TEXT -- Alameda County Office of Education
# 	"School Name" TEXT -- FAME Public Charter, Envision Academy for Arts & Technology
# 	"District Type" TEXT -- County Office of Education (COE)
# 	"School Type" TEXT -- K-12 Schools (Public), High Schools (Public), Elementary Schools (Public)
# 	"Educational Option Type" TEXT -- Traditional
# 	"NSLP Provision Status" TEXT -- Breakfast Provision 2
# 	"Charter School (Y/N)" INT -- 1
# 	"Charter School Number" TEXT -- 0728, 0811, 1049, 1284, 1296
# 	"Charter Funding Type" TEXT -- Directly funded
# 	IRC INT -- 1
# 	"Low Grade" TEXT -- K, 9
# 	"High Grade" TEXT -- 12, 8
# 	"Enrollment (K-12)" FLOAT -- 1087.0, 395.0, 244.0, 191.0, 257.0
# 	"Free Meal Count (K-12)" FLOAT -- 565.0, 186.0, 134.0, 113.0, 14.0
# 	"Percent (%) Eligible Free (K-12)" FLOAT -- 0.519779208831647, 0.470886075949367, 0.549180327868853
# 	"FRPM Count (K-12)" FLOAT -- 715.0, 186.0, 175.0, 139.0, 21.0
# 	"Percent (%) Eligible FRPM (K-12)" FLOAT -- 0.657773689052438, 0.470886075949367, 0.717213114754098
# 	"Enrollment (Ages 5-17)" FLOAT -- 1070.0, 376.0, 230.0, 190.0, 257.0
# 	"Free Meal Count (Ages 5-17)" FLOAT -- 553.0, 182.0, 128.0, 113.0, 14.0
# 	"Percent (%) Eligible Free (Ages 5-17)" FLOAT -- 0.516822429906542, 0.484042553191489, 0.556521739130435
# 	"FRPM Count (Ages 5-17)" FLOAT -- 702.0, 182.0, 168.0, 139.0, 21.0
# 	"Percent (%) Eligible FRPM (Ages 5-17)" FLOAT -- 0.65607476635514, 0.484042553191489, 0.730434782608696
# 	"2013-14 CALPADS Fall 1 Certification Status" INT
# 	FOREIGN KEY (CDSCode) REFERENCES schools (CDSCode)
# )
# satscores (
# 	cds TEXT -- 1100170000000, 1100170109835, 1100170112607, 1100170118489
# 	rtype TEXT -- D, S
# 	sname TEXT -- FAME Public Charter, Envision Academy for Arts & Technology
# 	dname TEXT -- Alameda County Office of Education, Alameda Unified
# 	cname TEXT -- Alameda
# 	enroll12 INT -- 398, 62, 75, 61, 922
# 	NumTstTakr INT -- 88, 17, 71, 0, 544
# 	AvgScrRead INT -- 418, 503, 397, 521
# 	AvgScrMath INT -- 418, 546, 387
# 	AvgScrWrite INT -- 417, 505, 395, 519
# 	NumGE1500 INT -- 14, 9, 5, 333
# 	FOREIGN KEY (cds) REFERENCES schools (CDSCode)
# )
# schools (
# 	CDSCode TEXT -- 01100170000000, 01100170109835, 01100170112607, 01100170118489
# 	NCESDist TEXT -- 0691051
# 	NCESSchool TEXT -- 10546, 10947, 12283, 12844
# 	StatusType TEXT -- Active, Closed
# 	County TEXT -- Alameda
# 	District TEXT -- Alameda County Office of Education
# 	School TEXT -- FAME Public Charter, Envision Academy for Arts & Technology
# 	Street TEXT -- 313 West Winton Avenue, "39899 Balentine Drive, Suite 335"
# 	StreetAbr TEXT -- 313 West Winton Ave., "39899 Balentine Dr., Ste. 335"
# 	City TEXT -- Hayward, Newark, Oakland, Berkeley
# 	Zip TEXT -- 94544-1136, 94560-5359, 94612-3355, 94703-1414, 94606-4903
# 	State TEXT -- CA
# 	MailStreet TEXT -- 313 West Winton Avenue, "39899 Balentine Drive, Suite 335"
# 	MailStrAbr TEXT -- 313 West Winton Ave., "39899 Balentine Dr., Ste. 335"
# 	MailCity TEXT -- Hayward, Newark, Oakland
# 	MailZip TEXT -- 94544-1136, 94560-5359, 94612, 94606, 94606-4903
# 	MailState TEXT -- CA
# 	Phone TEXT -- (510) 887-0152, (510) 596-8901, (510) 686-4131
# 	Ext TEXT
# 	Website TEXT -- www.acoe.org, www.envisionacademy.org/, www.aspirepublicschools.org
# 	OpenDate DATE -- 2005-08-29, 2006-08-28, 2008-08-21, 2011-08-22
# 	ClosedDate DATE -- 2015-07-31, 2015-06-30
# 	Charter INT -- 1
# 	CharterNum TEXT -- 0728, 0811, 1049, 1284
# 	FundingType TEXT -- Directly funded
# 	DOC TEXT -- 00
# 	DOCType TEXT -- County Office of Education (COE)
# 	SOC TEXT -- 65, 66, 60
# 	SOCType TEXT -- K-12 Schools (Public), High Schools (Public), Elementary Schools (Public)
# 	EdOpsCode TEXT -- TRAD
# 	EdOpsName TEXT -- Traditional
# 	EILCode TEXT -- ELEMHIGH, HS, ELEM
# 	EILName TEXT -- Elementary-High Combination, High School, Elementary
# 	GSoffered TEXT -- K-12, 9-12, K-8
# 	GSserved TEXT -- K-12, 9-12, K-7
# 	Virtual TEXT -- P, N
# 	Magnet INT -- 0
# 	Latitude FLOAT -- 37.658212, 37.521436, 37.80452, 37.868991, 37.784648
# 	Longitude FLOAT -- -122.09713, -121.99391, -122.26815, -122.27844, -122.23863
# 	AdmFName1 TEXT -- L Karen, Laura, Clifford
# 	AdmLName1 TEXT -- Monroe, Robell, Thompson
# 	AdmEmail1 TEXT -- lkmonroe@acoe.org, laura@envisionacademy.org, cliffordt@communityschoolforcreativeeducation.org
# 	AdmFName2 TEXT
# 	AdmLName2 TEXT
# 	AdmEmail2 TEXT
# 	AdmFName3 TEXT
# 	AdmLName3 TEXT
# 	AdmEmail3 TEXT
# 	LastUpdate DATE -- 2015-06-23, 2015-09-01, 2015-06-18, 2015-07-01, 2016-07-18
# )
#
# Of the schools that offers a magnet program serving a grade span of Kindergarten to 8th grade, how many offers Multiple Provision Types? List the number of cities that offers a Kindergarten to 8th grade span and indicate how many schools are there serving such grade span for each city.
# Kindergarten to 8th grade refers to K-8; 'Offers a magnet program' means Magnet = 1.
# SELECT T2.City, COUNT(T2.CDSCode) FROM frpm AS T1 INNER JOIN schools AS T2 ON T1.CDSCode = T2.CDSCode WHERE T2.Magnet = 1 AND T2.GSoffered = 'K-8' AND T1.`NSLP Provision Status` = 'Multiple Provision Types' GROUP BY T2.City
# SELECT City, COUNT(*) AS NumberOfSchools FROM schools WHERE GSoffered = 'K-8' AND Magnet = 1 GROUP BY City

# %%
df_pred['execution_accuracy'].mean()
# Out:
# 0.582
